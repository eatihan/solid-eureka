# %% [markdown]
# ## Bank Churn Prediction

# %% [markdown]
# #### Background and Context

# %% [markdown]
# Businesses like banks that provide service have to worry about the problem of 'Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on the improvement of service, keeping in mind these priorities.

# %% [markdown]
# #### Objective

# %% [markdown]
# Given a Bank customer, build a neural network-based classifier that can determine whether they will leave or not in the next 6 months.

# %% [markdown]
# #### Data Dictionary

# %% [markdown]
# - CustomerId: Unique ID which is assigned to each customer
# - Surname: Last name of the customer
# - CreditScore: It defines the credit history of the customer.
# - Geography: A customer’s location
# - Gender: It defines the Gender of the customer
# - Age: Age of the customer
# - Tenure: Number of years for which the customer has been with the bank
# - NumOfProducts: It refers to the number of products that a customer has purchased through the bank.
# - Balance: Account balance
# - HasCrCard: It is a categorical variable that decides whether the customer has a credit card or not.
# - EstimatedSalary: Estimated salary
# - isActiveMember: It is a categorical variable that decides whether the customer is an active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions, etc )
# - Excited: It is a categorical variable that decides whether the customer left the bank within six months or not. It can take two values
#                     0=No ( Customer did not leave the bank )
#
#                     1=Yes ( Customer left the bank )

# %% [markdown]
# ##### Import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# library to import to standardize the data
from sklearn.preprocessing import MinMaxScaler
from sklearn import model_selection
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import warnings
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import random
from tensorflow.keras import backend
random.seed(1)
np.random.seed(1) 
tf.random.set_seed(1)
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Churn.csv')

# %%
data = df.copy()

# %%
# Checking the number of rows and columns in the data
data.shape
# Out:
# (10000, 14)

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Let's check for duplicate values in the data
data.duplicated().sum()
# Out:
# 0

# %%
# Let's check for missing values in the data
round(data.isnull().sum() / data.isnull().count() * 100, 2)
# Out:
# RowNumber          0.0
# CustomerId         0.0
# Surname            0.0
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %%
data["Exited"].value_counts(1)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %%
# Let's view the statistical summary of the numerical columns in the data
data.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# CreditScore           584.00  6.520000e+02  7.180000e+02       850.00
# Age                    32.00  3.700000e+01  4.400000e+01        92.00
# Tenure                  3.00  5.000000e+00  7.000000e+00        10.00
# Balance                 0.00  9.719854e+04  1.276442e+05    250898.09
# NumOfProducts           1.00  1.000000e+00  2.000000e+00         4.00
# HasCrCard               0.00  1.000000e+00  1.000000e+00         1.00
# IsActiveMember          0.00  1.000000e+00  1.000000e+00         1.00
# EstimatedSalary     51002.11  1.001939e+05  1.493882e+05    199992.48
# Exited                  0.00  0.000000e+00  0.000000e+00         1.00

# %%
# Let's check the number of unique values in each column
data.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
for i in data.describe(include=["object"]).columns:
    print("Unique values in", i, "are :")
    print(data[i].value_counts())
    print("*" * 50)
# Out:
# Unique values in Surname are :
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: Surname, Length: 2932, dtype: int64
# **************************************************
# Unique values in Geography are :
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# **************************************************
# Unique values in Gender are :
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# **************************************************

# %% [markdown]
# ##### Dropping the unique columns

# %%
# ID column consists of uniques ID for clients and hence will not add value to the modeling
data.drop(columns="RowNumber", inplace=True)
data.drop(columns="CustomerId", inplace=True)
data.drop(columns="Surname", inplace=True)

# %% [markdown]
# - RowNumber, CustomerId and Surname are unique to each customer and hence will not add vlue to the modeling/analysis

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Univariate Analysis

# %%
# Function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
data.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
histogram_boxplot(data, 'CreditScore')

# %% [markdown]
# - The data is normally distributed with mean around 6.5k.

# %%
histogram_boxplot(data, 'Age')

# %% [markdown]
# - The data is slightly right skewed with mean greater median. The median age is 37 years with some outliers.

# %%
histogram_boxplot(data, 'Tenure')

# %% [markdown]
# - The tenure is range between 0 - 10 years. The mean and median is 5 years.

# %%
histogram_boxplot(data, 'NumOfProducts')

# %%
histogram_boxplot(data, 'EstimatedSalary')

# %% [markdown]
# - The max estimated salary is 200k and the mean and median are around 100k.

# %%
# Function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
labeled_barplot(data, 'Geography', perc=True)

# %% [markdown]
# - 50% of the customers are from France.
# - The other 50% of the customers are equally from Germany and Spain.

# %%
labeled_barplot(data, 'Gender', perc=True)

# %% [markdown]
# - 55% of the customers are male and the remaining are Female.

# %% [markdown]
# ### Bivariate Analysis

# %%
corr_cols = []
for col in data.columns:
    if data[col].dtypes != 'object':
        corr_cols.append(col)
        
plt.figure(figsize=(15, 7))
sns.heatmap(
    data[corr_cols].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %% [markdown]
# - The numerical columns of the data seem to be independent of each other overall.
# - The age column shows slight +ve correlation if the customer is going to churn or not. Similarly how active a member is also -vely correlated with if he/she is going to churn or not.

# %%
### Function to plot distributions


def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of Exited for Exited=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
    )

    axs[0, 1].set_title("Distribution of Exited for Exited=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
    )

    axs[1, 0].set_title("Boxplot w.r.t Exited")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t Exited")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %%
distribution_plot_wrt_target(data, "CreditScore", "Exited")

# %% [markdown]
# We observe that the distribution of the credit score with respect to the target variable is slightly left skewed, and from the box plot for both classes the median credit score are around 650.

# %%
distribution_plot_wrt_target(data, "Age", "Exited")

# %% [markdown]
# We observe that the distribution of the Age with respect to the target variable is rightly skewed, and from the box plot for both class 0 the median Age is around 35 and for class 1 the median Age is 45.

# %%
distribution_plot_wrt_target(data, "Tenure", "Exited")

# %% [markdown]
# We observe that the distribution of the Tenure with respect to the target variable is evenely distributed, and from the box plot for both classes the median Tenure is 5 years.

# %%
distribution_plot_wrt_target(data, "EstimatedSalary", "Exited")

# %% [markdown]
# We observe that the distribution of the Estimated Salary with respect to the target variable is evenly distributed, and from the box plot for both classes the median estimated salary is around 100k.

# %%
# function to plot stacked bar chart


def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left",
        frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
stacked_barplot(data, "Geography", "Exited")
# Out:
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Almost twice the number of customers from Germany churned compared to Spain and France.

# %%
stacked_barplot(data, "Gender", "Exited")
# Out:
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - More female customers churned compared to male customers.

# %% [markdown]
# ### If the data is imbalanced ?

# %%
print(data.Exited.value_counts())
labels = 'Customer left the bank', 'Customer did not leave the bank'
#sizes = [ds.is_promoted[ds['is_promoted']==1].count(), ds.is_promoted[ds['is_promoted']==0].count()]
sizes = [data.Exited[data['Exited']==1].count(),data.Exited[data['Exited']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Proportion", size = 20)
plt.show()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# ### Data Pre-processing

# %%
## Separating Independent and Dependent Columns
X = data.drop(['Exited'],axis=1)
Y = data[['Exited']]

# %%
Y.head()
# Out:
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
# Splitting the dataset into the Training and Testing set.

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42,stratify = Y)

# %%
X_train.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64

# %%
# Checking that no column has missing values in train and test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64
# ------------------------------
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64

# %% [markdown]
# #### Encoding Categorical Columns

# %%
labelencoder_G = LabelEncoder()
X_train['Geography']=  labelencoder_G.fit_transform(X_train['Geography'])
X_test['Geography']=  labelencoder_G.transform(X_test['Geography'])

# %%
labelencoder_A = LabelEncoder()
X_train['Gender']=  labelencoder_A.fit_transform(X_train['Gender'])
X_test['Gender']=  labelencoder_A.transform(X_test['Gender'])

# %%
X_train.head()
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 2151          753          0       1   57       7       0.00              1
# 8392          739          1       1   32       3  102128.27              1
# 5006          755          1       0   37       0  113865.23              2
# 4117          561          0       1   37       5       0.00              2
# 7182          692          1       1   49       6  110540.43              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 2151          1               0        159475.08
# 8392          1               0         63981.37
# 5006          1               1        117396.25
# 4117          1               0         83093.25
# 7182          0               1        107472.99

# %%
data["Geography"].value_counts(1)
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %%
y_train.head()
# Out:
#       Exited
# 2151       1
# 8392       1
# 5006       0
# 4117       0
# 7182       0

# %%
###Checking the shape of train and test sets
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000, 10)
# (2000, 10)
# (8000, 1)
# (2000, 1)

# %% [markdown]
# #### Scaling

# %%
scaler = MinMaxScaler()

# Here, we are passing all the features (numerical and categorical), that's okay as min-max scaler will not change values of categorical variables
X_train_normalized = scaler.fit_transform(X_train)

# %%
X_test_normalized = scaler.transform(X_test)

# %%
np.set_printoptions(suppress=True)
print(X_train_normalized)
# Out:
# [[0.806      0.         1.         ... 1.         0.         0.79739365]
#  [0.778      0.5        1.         ... 1.         0.         0.3198795 ]
#  [0.81       0.5        0.         ... 1.         1.         0.58697941]
#  ...
#  [0.634      0.         0.         ... 1.         1.         0.33864839]
#  [0.674      1.         1.         ... 1.         0.         0.11118907]
#  [0.904      1.         1.         ... 0.         1.         0.20424055]]

# %%
X_train_normalized_df = pd.DataFrame(X_train_normalized, index=X_train.index, columns=X_train.columns)
X_test_normalized_df = pd.DataFrame(X_test_normalized, index=X_test.index, columns=X_test.columns)

# %%
X_train_normalized_df.head()
# Out:
#       CreditScore  Geography  Gender       Age  Tenure   Balance  \
# 2151        0.806        0.0     1.0  0.527027     0.7  0.000000
# 8392        0.778        0.5     1.0  0.189189     0.3  0.428413
# 5006        0.810        0.5     0.0  0.256757     0.0  0.477648
# 4117        0.422        0.0     1.0  0.256757     0.5  0.000000
# 7182        0.684        0.5     1.0  0.418919     0.6  0.463700
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 2151       0.000000        1.0             0.0         0.797394
# 8392       0.000000        1.0             0.0         0.319879
# 5006       0.333333        1.0             1.0         0.586979
# 4117       0.333333        1.0             0.0         0.415448
# 7182       0.333333        0.0             1.0         0.537358

# %%
X_test_normalized_df.head()
# Out:
#       CreditScore  Geography  Gender       Age  Tenure   Balance  \
# 5702        0.470        0.0     1.0  0.243243     0.7  0.000000
# 3667        0.350        0.5     1.0  0.202703     0.4  0.549625
# 1617        0.414        1.0     0.0  0.297297     0.4  0.000000
# 5673        0.578        1.0     1.0  0.216216     0.5  0.584733
# 4272        0.580        1.0     0.0  0.216216     0.3  0.326472
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 5702       0.333333        1.0             0.0         0.471403
# 3667       0.333333        0.0             0.0         0.275333
# 1617       0.333333        0.0             1.0         0.527160
# 5673       0.333333        0.0             0.0         0.169709
# 4272       0.000000        1.0             1.0         0.842747

# %%
X_train.head()
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 2151          753          0       1   57       7       0.00              1
# 8392          739          1       1   32       3  102128.27              1
# 5006          755          1       0   37       0  113865.23              2
# 4117          561          0       1   37       5       0.00              2
# 7182          692          1       1   49       6  110540.43              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 2151          1               0        159475.08
# 8392          1               0         63981.37
# 5006          1               1        117396.25
# 4117          1               0         83093.25
# 7182          0               1        107472.99

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model evaluation criterion:

# %% [markdown]
# #### A model can make wrong predictions in the following ways:

# %% [markdown]
# 1. Predicting a customer is going to churn but in reality, the customer is not going to churn - Loss of resources
# 2. Predicting a customer is not going to churn but in reality the customer is going to churn - Loss of opportunity

# %% [markdown]
# #### Which case is more important?

# %% [markdown]
# - Predicting a customer is not going to churn but in reality the customer is going to churn i.e. losing on a potential opportunity as the customer will not be targeted by the Bank when he should be targeted.

# %% [markdown]
# #### How to reduce this loss i.e need to reduce False Negatives?

# %% [markdown]
# - Bank would want Recall to be maximized, greater the Recall lesser the chances of false negatives.

# %% [markdown]
# ### Model 1

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the ANN
model1 = Sequential()
# The amount of nodes (dimensions) in hidden layer should be the average of input and output layers, in this case 64.
# This adds the input layer (by specifying input dimension) AND the first hidden layer (units)
model1.add(Dense(activation = 'relu', input_dim = X_train.shape[1], units=64))
#Add 1st hidden layer
model1.add(Dense(32, activation='relu'))
# Adding the output layer
# Notice that we do not need to specify input dim. 
# we have an output of 1 node, which is the the desired dimensions of our output (stay with the bank or not)
# We use the sigmoid because we want probability outcomes
model1.add(Dense(1, activation = 'sigmoid'))

# %%
# Create optimizer with default learning rate
# Compile the model
model1.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                704
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,817
# Trainable params: 2,817
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model1.fit(X_train_normalized_df, y_train,           
          validation_split=0.2,
          epochs=50,
          batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5217 - accuracy: 0.7919 - val_loss: 0.4900 - val_accuracy: 0.8000
# Epoch 2/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4930 - accuracy: 0.7953 - val_loss: 0.4844 - val_accuracy: 0.8000
# Epoch 3/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4868 - accuracy: 0.7953 - val_loss: 0.4795 - val_accuracy: 0.8000
# Epoch 4/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4815 - accuracy: 0.7953 - val_loss: 0.4752 - val_accuracy: 0.8000
# Epoch 5/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4768 - accuracy: 0.7953 - val_loss: 0.4717 - val_accuracy: 0.8000
# Epoch 6/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4726 - accuracy: 0.7953 - val_loss: 0.4686 - val_accuracy: 0.8000
# Epoch 7/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4691 - accuracy: 0.7953 - val_loss: 0.4661 - val_accuracy: 0.8000
# Epoch 8/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4657 - accuracy: 0.7953 - val_loss: 0.4634 - val_accuracy: 0.8000
# Epoch 9/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4627 - accuracy: 0.7953 - val_loss: 0.4615 - val_accuracy: 0.8012
# Epoch 10/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4600 - accuracy: 0.7955 - val_loss: 0.4590 - val_accuracy: 0.8012
# Epoch 11/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4574 - accuracy: 0.7966 - val_loss: 0.4573 - val_accuracy: 0.8025
# Epoch 12/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4547 - accuracy: 0.7975 - val_loss: 0.4552 - val_accuracy: 0.8050
# Epoch 13/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4524 - accuracy: 0.7997 - val_loss: 0.4533 - val_accuracy: 0.8062
# Epoch 14/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4499 - accuracy: 0.8025 - val_loss: 0.4518 - val_accuracy: 0.8081
# Epoch 15/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4478 - accuracy: 0.8041 - val_loss: 0.4508 - val_accuracy: 0.8150
# Epoch 16/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4458 - accuracy: 0.8053 - val_loss: 0.4497 - val_accuracy: 0.8163
# Epoch 17/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4442 - accuracy: 0.8053 - val_loss: 0.4482 - val_accuracy: 0.8175
# Epoch 18/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4423 - accuracy: 0.8066 - val_loss: 0.4463 - val_accuracy: 0.8163
# Epoch 19/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4409 - accuracy: 0.8061 - val_loss: 0.4453 - val_accuracy: 0.8150
# Epoch 20/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4393 - accuracy: 0.8091 - val_loss: 0.4442 - val_accuracy: 0.8138
# Epoch 21/50
# 200/200 [==============================] - 0s 3ms/step - loss: 0.4378 - accuracy: 0.8095 - val_loss: 0.4437 - val_accuracy: 0.8156
# Epoch 22/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4367 - accuracy: 0.8080 - val_loss: 0.4426 - val_accuracy: 0.8144
# Epoch 23/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4356 - accuracy: 0.8103 - val_loss: 0.4425 - val_accuracy: 0.8125
# Epoch 24/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4349 - accuracy: 0.8103 - val_loss: 0.4420 - val_accuracy: 0.8125
# Epoch 25/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4338 - accuracy: 0.8089 - val_loss: 0.4412 - val_accuracy: 0.8138
# Epoch 26/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4326 - accuracy: 0.8089 - val_loss: 0.4400 - val_accuracy: 0.8144
# Epoch 27/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4319 - accuracy: 0.8112 - val_loss: 0.4408 - val_accuracy: 0.8150
# Epoch 28/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4308 - accuracy: 0.8108 - val_loss: 0.4388 - val_accuracy: 0.8125
# Epoch 29/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4303 - accuracy: 0.8111 - val_loss: 0.4383 - val_accuracy: 0.8119
# Epoch 30/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4295 - accuracy: 0.8098 - val_loss: 0.4381 - val_accuracy: 0.8138
# Epoch 31/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4283 - accuracy: 0.8109 - val_loss: 0.4380 - val_accuracy: 0.8150
# Epoch 32/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4276 - accuracy: 0.8103 - val_loss: 0.4385 - val_accuracy: 0.8144
# Epoch 33/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4272 - accuracy: 0.8116 - val_loss: 0.4363 - val_accuracy: 0.8144
# Epoch 34/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4260 - accuracy: 0.8119 - val_loss: 0.4356 - val_accuracy: 0.8138
# Epoch 35/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4257 - accuracy: 0.8122 - val_loss: 0.4346 - val_accuracy: 0.8156
# Epoch 36/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4252 - accuracy: 0.8125 - val_loss: 0.4340 - val_accuracy: 0.8150
# Epoch 37/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4247 - accuracy: 0.8127 - val_loss: 0.4332 - val_accuracy: 0.8156
# Epoch 38/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4237 - accuracy: 0.8131 - val_loss: 0.4327 - val_accuracy: 0.8169
# Epoch 39/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4228 - accuracy: 0.8148 - val_loss: 0.4341 - val_accuracy: 0.8163
# Epoch 40/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4219 - accuracy: 0.8156 - val_loss: 0.4347 - val_accuracy: 0.8181
# Epoch 41/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4218 - accuracy: 0.8145 - val_loss: 0.4315 - val_accuracy: 0.8188
# Epoch 42/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4204 - accuracy: 0.8155 - val_loss: 0.4299 - val_accuracy: 0.8194
# Epoch 43/50
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4204 - accuracy: 0.8166 - val_loss: 0.4286 - val_accuracy: 0.8188
# Epoch 44/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4191 - accuracy: 0.8177 - val_loss: 0.4278 - val_accuracy: 0.8188
# Epoch 45/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4187 - accuracy: 0.8158 - val_loss: 0.4268 - val_accuracy: 0.8200
# Epoch 46/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4179 - accuracy: 0.8198 - val_loss: 0.4257 - val_accuracy: 0.8194
# Epoch 47/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4169 - accuracy: 0.8197 - val_loss: 0.4261 - val_accuracy: 0.8138
# Epoch 48/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4163 - accuracy: 0.8195 - val_loss: 0.4238 - val_accuracy: 0.8225
# Epoch 49/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4151 - accuracy: 0.8186 - val_loss: 0.4229 - val_accuracy: 0.8256
# Epoch 50/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4138 - accuracy: 0.8200 - val_loss: 0.4218 - val_accuracy: 0.8225

# %%
# Capturing learning history per epoch
hist  = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# Plotting accuracy at different epochs
plt.plot(hist['loss'])
plt.plot(hist['val_loss'])
plt.legend(("train" , "valid") , loc =0)

#Printing results
results = model1.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 16302.6123 - accuracy: 0.2045

# %%
y_pred=model1.predict(X_test_normalized_df)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))



    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    
    if title:
        plt.title(title)

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %% [markdown]
# Here, the 21.8% of False Negatives is because we gave 0.5 as the threshold to the model, and as this is an imbalanced dataset, we should calculate the threshold using the AUC-ROC curve.

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      1593
#            1       0.71      0.19      0.31       407
#
#     accuracy                           0.82      2000
#    macro avg       0.77      0.59      0.60      2000
# weighted avg       0.80      0.82      0.78      2000

# %% [markdown]
# As we can see, the above model has a relatively poor recall score. This could be due to the imbalanced dataset. We observe that the False negative rates are also high, which should be considerably lower.
#
# 1) Imbalanced dataset: As you have seen in the EDA, this dataset is imbalanced, and it contains more examples that belong to the 0 class.
#
# 2) Decision Threshold: Due to the imbalanced dataset, we can use ROC-AUC to find the optimal threshold and use the same for prediction.
#
# Let's try to change the optimizer, tune the decision threshold, increase the layers and configure some other hyperparameters accordingly, in order to improve the model's performance.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat1 = model1.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat1 = yhat1[:, 0]
# calculate roc curves
fpr, tpr, thresholds1 = roc_curve(y_test, yhat1)
# calculate the g-mean for each threshold
gmeans1 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans1)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds1[ix], gmeans1[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.212659, G-Mean=0.724

# %%
#Predicting the results using best as a threshold
y_pred_e1=model1.predict(X_test_normalized_df)
y_pred_e1 = (y_pred_e1 > thresholds1[ix])
y_pred_e1
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred_e1)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred_e1)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82      1593
#            1       0.42      0.70      0.52       407
#
#     accuracy                           0.74      2000
#    macro avg       0.66      0.72      0.67      2000
# weighted avg       0.81      0.74      0.76      2000

# %% [markdown]
# - Using the ROC-AUC threshold, we can see the False negatives have increased however, there is some improvement in macro recall score.

# %% [markdown]
# ### Model 2

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model1 = Sequential()
      #Adding the hidden and output layers
model1.add(Dense(256,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model1.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(1, activation = 'sigmoid'))
      #Compiling the ANN with Adam optimizer and binary cross entropy loss function 
optimizer = tf.keras.optimizers.Adam(0.001)
model1.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2816
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model1.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4714 - accuracy: 0.7952 - val_loss: 0.4583 - val_accuracy: 0.8050
# Epoch 2/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4273 - accuracy: 0.8239 - val_loss: 0.4072 - val_accuracy: 0.8313
# Epoch 3/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3960 - accuracy: 0.8284 - val_loss: 0.3772 - val_accuracy: 0.8494
# Epoch 4/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3702 - accuracy: 0.8484 - val_loss: 0.3653 - val_accuracy: 0.8531
# Epoch 5/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3614 - accuracy: 0.8522 - val_loss: 0.3540 - val_accuracy: 0.8631
# Epoch 6/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3593 - accuracy: 0.8506 - val_loss: 0.3486 - val_accuracy: 0.8606
# Epoch 7/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3509 - accuracy: 0.8503 - val_loss: 0.3556 - val_accuracy: 0.8556
# Epoch 8/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3471 - accuracy: 0.8575 - val_loss: 0.3473 - val_accuracy: 0.8631
# Epoch 9/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3397 - accuracy: 0.8570 - val_loss: 0.3503 - val_accuracy: 0.8587
# Epoch 10/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3364 - accuracy: 0.8609 - val_loss: 0.3410 - val_accuracy: 0.8625
# Epoch 11/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3312 - accuracy: 0.8606 - val_loss: 0.3509 - val_accuracy: 0.8675
# Epoch 12/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3290 - accuracy: 0.8633 - val_loss: 0.3462 - val_accuracy: 0.8650
# Epoch 13/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3284 - accuracy: 0.8644 - val_loss: 0.3606 - val_accuracy: 0.8544
# Epoch 14/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3264 - accuracy: 0.8647 - val_loss: 0.3445 - val_accuracy: 0.8587
# Epoch 15/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3158 - accuracy: 0.8697 - val_loss: 0.3619 - val_accuracy: 0.8594
# Epoch 16/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3180 - accuracy: 0.8642 - val_loss: 0.3569 - val_accuracy: 0.8587
# Epoch 17/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3153 - accuracy: 0.8667 - val_loss: 0.3508 - val_accuracy: 0.8625
# Epoch 18/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3098 - accuracy: 0.8669 - val_loss: 0.3501 - val_accuracy: 0.8731
# Epoch 19/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3053 - accuracy: 0.8720 - val_loss: 0.3570 - val_accuracy: 0.8581
# Epoch 20/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3036 - accuracy: 0.8725 - val_loss: 0.3644 - val_accuracy: 0.8594
# Epoch 21/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2985 - accuracy: 0.8734 - val_loss: 0.3577 - val_accuracy: 0.8637
# Epoch 22/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2977 - accuracy: 0.8763 - val_loss: 0.3696 - val_accuracy: 0.8612
# Epoch 23/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2926 - accuracy: 0.8733 - val_loss: 0.3684 - val_accuracy: 0.8637
# Epoch 24/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2890 - accuracy: 0.8806 - val_loss: 0.3637 - val_accuracy: 0.8606
# Epoch 25/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2881 - accuracy: 0.8781 - val_loss: 0.3984 - val_accuracy: 0.8369
# Epoch 26/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2883 - accuracy: 0.8770 - val_loss: 0.3856 - val_accuracy: 0.8569
# Epoch 27/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2814 - accuracy: 0.8841 - val_loss: 0.3833 - val_accuracy: 0.8525
# Epoch 28/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2785 - accuracy: 0.8817 - val_loss: 0.3889 - val_accuracy: 0.8519
# Epoch 29/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2775 - accuracy: 0.8842 - val_loss: 0.3820 - val_accuracy: 0.8581
# Epoch 30/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2716 - accuracy: 0.8823 - val_loss: 0.3811 - val_accuracy: 0.8587
# Epoch 31/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2675 - accuracy: 0.8891 - val_loss: 0.3954 - val_accuracy: 0.8475
# Epoch 32/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2661 - accuracy: 0.8873 - val_loss: 0.3957 - val_accuracy: 0.8594
# Epoch 33/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2607 - accuracy: 0.8936 - val_loss: 0.4066 - val_accuracy: 0.8531
# Epoch 34/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2603 - accuracy: 0.8911 - val_loss: 0.3960 - val_accuracy: 0.8587
# Epoch 35/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2575 - accuracy: 0.8914 - val_loss: 0.3995 - val_accuracy: 0.8556
# Epoch 36/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2523 - accuracy: 0.8952 - val_loss: 0.4138 - val_accuracy: 0.8625
# Epoch 37/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2464 - accuracy: 0.8948 - val_loss: 0.4186 - val_accuracy: 0.8419
# Epoch 38/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2472 - accuracy: 0.8964 - val_loss: 0.4078 - val_accuracy: 0.8544
# Epoch 39/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2444 - accuracy: 0.8986 - val_loss: 0.4260 - val_accuracy: 0.8406
# Epoch 40/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2382 - accuracy: 0.9011 - val_loss: 0.4265 - val_accuracy: 0.8469
# Epoch 41/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2367 - accuracy: 0.8998 - val_loss: 0.4349 - val_accuracy: 0.8519
# Epoch 42/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2344 - accuracy: 0.8991 - val_loss: 0.4420 - val_accuracy: 0.8481
# Epoch 43/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2270 - accuracy: 0.9031 - val_loss: 0.4476 - val_accuracy: 0.8438
# Epoch 44/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2259 - accuracy: 0.9044 - val_loss: 0.4450 - val_accuracy: 0.8400
# Epoch 45/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2232 - accuracy: 0.9038 - val_loss: 0.4528 - val_accuracy: 0.8494
# Epoch 46/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2181 - accuracy: 0.9117 - val_loss: 0.4643 - val_accuracy: 0.8487
# Epoch 47/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2165 - accuracy: 0.9081 - val_loss: 0.4629 - val_accuracy: 0.8531
# Epoch 48/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.9080 - val_loss: 0.4677 - val_accuracy: 0.8431
# Epoch 49/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2060 - accuracy: 0.9131 - val_loss: 0.4812 - val_accuracy: 0.8500
# Epoch 50/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2082 - accuracy: 0.9134 - val_loss: 0.4932 - val_accuracy: 0.8325

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - As we increased the number of layers, we see from the diverging train and validation curves that the model is over-fitted.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat1 = model1.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat1 = yhat1[:, 0]
# calculate roc curves
fpr, tpr, thresholds1 = roc_curve(y_test, yhat1)
# calculate the g-mean for each threshold
gmeans1 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans1)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds1[ix], gmeans1[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.222609, G-Mean=0.704

# %%
#Predicting the results using best as a threshold
y_pred_e1=model1.predict(X_test_normalized_df)
y_pred_e1 = (y_pred_e1 > thresholds1[ix])
y_pred_e1
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [ True],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(y_test, y_pred_e1)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm1, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred_e1)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.79      0.84      1593
#            1       0.43      0.62      0.51       407
#
#     accuracy                           0.76      2000
#    macro avg       0.66      0.71      0.67      2000
# weighted avg       0.80      0.76      0.77      2000

# %% [markdown]
# As the number of layers in the neural network has increased, we can see that the macro recall score has decreased slightly but the False Negative percentage has improved (i.e. percentage reduced.)
#
# Now let's try to use the Batch Normalization technique and check to see if we can increase the recall score.

# %% [markdown]
# ### Model 3

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model3 = Sequential()
model3.add(Dense(128,activation='relu',input_dim = X_train.shape[1]))
model3.add(BatchNormalization())
model3.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model3.add(BatchNormalization())
model3.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
model3.add(Dense(1, activation = 'sigmoid'))

# %%
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 12,545
# Trainable params: 12,161
# Non-trainable params: 384
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_3 = model2.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0851 - accuracy: 0.9641 - val_loss: 0.9964 - val_accuracy: 0.8231
# Epoch 2/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0815 - accuracy: 0.9681 - val_loss: 0.9769 - val_accuracy: 0.8138
# Epoch 3/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0817 - accuracy: 0.9711 - val_loss: 0.9683 - val_accuracy: 0.8181
# Epoch 4/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0756 - accuracy: 0.9709 - val_loss: 1.0286 - val_accuracy: 0.8056
# Epoch 5/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0812 - accuracy: 0.9670 - val_loss: 0.9941 - val_accuracy: 0.8100
# Epoch 6/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0829 - accuracy: 0.9683 - val_loss: 1.0215 - val_accuracy: 0.8156
# Epoch 7/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0631 - accuracy: 0.9770 - val_loss: 1.0331 - val_accuracy: 0.8231
# Epoch 8/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 0.9744 - val_loss: 1.0547 - val_accuracy: 0.8181
# Epoch 9/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0595 - accuracy: 0.9786 - val_loss: 1.0826 - val_accuracy: 0.8281
# Epoch 10/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0561 - accuracy: 0.9784 - val_loss: 1.0663 - val_accuracy: 0.8294
# Epoch 11/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.9797 - val_loss: 1.1206 - val_accuracy: 0.8325
# Epoch 12/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0663 - accuracy: 0.9748 - val_loss: 1.1084 - val_accuracy: 0.8156
# Epoch 13/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0629 - accuracy: 0.9748 - val_loss: 1.1359 - val_accuracy: 0.8156
# Epoch 14/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0591 - accuracy: 0.9780 - val_loss: 1.1687 - val_accuracy: 0.8250
# Epoch 15/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0661 - accuracy: 0.9756 - val_loss: 1.1759 - val_accuracy: 0.8125
# Epoch 16/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 0.9770 - val_loss: 1.1542 - val_accuracy: 0.8112
# Epoch 17/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0712 - accuracy: 0.9739 - val_loss: 1.1484 - val_accuracy: 0.8156
# Epoch 18/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.9692 - val_loss: 1.0873 - val_accuracy: 0.8056
# Epoch 19/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0587 - accuracy: 0.9761 - val_loss: 1.1695 - val_accuracy: 0.8369
# Epoch 20/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9852 - val_loss: 1.1607 - val_accuracy: 0.8150
# Epoch 21/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9852 - val_loss: 1.2188 - val_accuracy: 0.8200
# Epoch 22/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0681 - accuracy: 0.9739 - val_loss: 1.1406 - val_accuracy: 0.8225
# Epoch 23/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0729 - accuracy: 0.9733 - val_loss: 1.1815 - val_accuracy: 0.8069
# Epoch 24/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0619 - accuracy: 0.9737 - val_loss: 1.1591 - val_accuracy: 0.8131
# Epoch 25/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0640 - accuracy: 0.9755 - val_loss: 1.2028 - val_accuracy: 0.8094
# Epoch 26/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9808 - val_loss: 1.2363 - val_accuracy: 0.8206
# Epoch 27/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9755 - val_loss: 1.2414 - val_accuracy: 0.8125
# Epoch 28/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9839 - val_loss: 1.2580 - val_accuracy: 0.8100
# Epoch 29/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9825 - val_loss: 1.2616 - val_accuracy: 0.8094
# Epoch 30/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9839 - val_loss: 1.2643 - val_accuracy: 0.8163
# Epoch 31/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 0.9886 - val_loss: 1.2651 - val_accuracy: 0.8150
# Epoch 32/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0393 - accuracy: 0.9867 - val_loss: 1.2663 - val_accuracy: 0.8194
# Epoch 33/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0367 - accuracy: 0.9870 - val_loss: 1.3404 - val_accuracy: 0.8037
# Epoch 34/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9817 - val_loss: 1.3602 - val_accuracy: 0.8244
# Epoch 35/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0667 - accuracy: 0.9734 - val_loss: 1.3804 - val_accuracy: 0.8175
# Epoch 36/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0724 - accuracy: 0.9742 - val_loss: 1.3106 - val_accuracy: 0.8244
# Epoch 37/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0676 - accuracy: 0.9752 - val_loss: 1.3467 - val_accuracy: 0.7994
# Epoch 38/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 0.9816 - val_loss: 1.2991 - val_accuracy: 0.8281
# Epoch 39/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0534 - accuracy: 0.9792 - val_loss: 1.2750 - val_accuracy: 0.8238
# Epoch 40/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0436 - accuracy: 0.9850 - val_loss: 1.2782 - val_accuracy: 0.8200
# Epoch 41/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0420 - accuracy: 0.9844 - val_loss: 1.3044 - val_accuracy: 0.8225
# Epoch 42/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9867 - val_loss: 1.3631 - val_accuracy: 0.8213
# Epoch 43/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9859 - val_loss: 1.3865 - val_accuracy: 0.8225
# Epoch 44/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0334 - accuracy: 0.9902 - val_loss: 1.3764 - val_accuracy: 0.8131
# Epoch 45/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9850 - val_loss: 1.3943 - val_accuracy: 0.8225
# Epoch 46/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 0.9877 - val_loss: 1.3875 - val_accuracy: 0.8112
# Epoch 47/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0444 - accuracy: 0.9841 - val_loss: 1.4206 - val_accuracy: 0.8131
# Epoch 48/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9892 - val_loss: 1.3807 - val_accuracy: 0.8163
# Epoch 49/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 0.9925 - val_loss: 1.4484 - val_accuracy: 0.8200
# Epoch 50/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.9898 - val_loss: 1.4453 - val_accuracy: 0.8156

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - Unfortunately, from the above plot we seem to have overfitted on the training data because there is a significant difference in performance between train and validation.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat3 = model3.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat3 = yhat3[:, 0]
# calculate roc curves
fpr, tpr, thresholds3 = roc_curve(y_test, yhat3)
# calculate the g-mean for each threshold
gmeans3 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans3)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds3[ix], gmeans3[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.497093, G-Mean=0.584

# %%
y_pred_e3=model3.predict(X_test_normalized_df)
y_pred_e3 = (y_pred_e3 > thresholds3[ix])
y_pred_e3
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm3=confusion_matrix(y_test, y_pred_e3)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm3, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr3=metrics.classification_report(y_test,y_pred_e3)
print(cr3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.61      0.71      1593
#            1       0.27      0.55      0.36       407
#
#     accuracy                           0.60      2000
#    macro avg       0.56      0.58      0.54      2000
# weighted avg       0.73      0.60      0.64      2000

# %% [markdown]
# The model shows a poor recall scrore and a high False Negative rate.
#
# Let's try to use the Dropout technique and check to see if it can reduce the False Negative rate.

# %% [markdown]
# ### Model 4

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model4 = Sequential()
model4.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
model4.add(Dropout(0.3))
model4.add(Dense(128,activation='relu'))
model4.add(Dropout(0.3))
model4.add(Dense(64,activation='relu'))
model4.add(Dropout(0.3))
model4.add(Dense(32,activation='relu'))
model4.add(Dense(1, activation = 'sigmoid'))

# %%
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2816
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_4 = model4.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 7ms/step - loss: 0.5051 - accuracy: 0.7883 - val_loss: 0.4650 - val_accuracy: 0.8000
# Epoch 2/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4615 - accuracy: 0.7952 - val_loss: 0.4537 - val_accuracy: 0.8006
# Epoch 3/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4448 - accuracy: 0.8039 - val_loss: 0.4284 - val_accuracy: 0.8269
# Epoch 4/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4310 - accuracy: 0.8186 - val_loss: 0.4100 - val_accuracy: 0.8444
# Epoch 5/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4172 - accuracy: 0.8270 - val_loss: 0.3927 - val_accuracy: 0.8550
# Epoch 6/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4033 - accuracy: 0.8331 - val_loss: 0.3717 - val_accuracy: 0.8550
# Epoch 7/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3915 - accuracy: 0.8364 - val_loss: 0.3624 - val_accuracy: 0.8650
# Epoch 8/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3831 - accuracy: 0.8408 - val_loss: 0.3542 - val_accuracy: 0.8594
# Epoch 9/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3775 - accuracy: 0.8425 - val_loss: 0.3518 - val_accuracy: 0.8637
# Epoch 10/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3719 - accuracy: 0.8511 - val_loss: 0.3477 - val_accuracy: 0.8675
# Epoch 11/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3727 - accuracy: 0.8481 - val_loss: 0.3495 - val_accuracy: 0.8712
# Epoch 12/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3690 - accuracy: 0.8509 - val_loss: 0.3535 - val_accuracy: 0.8631
# Epoch 13/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3708 - accuracy: 0.8452 - val_loss: 0.3546 - val_accuracy: 0.8656
# Epoch 14/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3676 - accuracy: 0.8492 - val_loss: 0.3523 - val_accuracy: 0.8681
# Epoch 15/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3611 - accuracy: 0.8536 - val_loss: 0.3440 - val_accuracy: 0.8669
# Epoch 16/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3619 - accuracy: 0.8512 - val_loss: 0.3429 - val_accuracy: 0.8619
# Epoch 17/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3569 - accuracy: 0.8550 - val_loss: 0.3425 - val_accuracy: 0.8675
# Epoch 18/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3616 - accuracy: 0.8533 - val_loss: 0.3432 - val_accuracy: 0.8669
# Epoch 19/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3597 - accuracy: 0.8541 - val_loss: 0.3399 - val_accuracy: 0.8625
# Epoch 20/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3546 - accuracy: 0.8561 - val_loss: 0.3400 - val_accuracy: 0.8656
# Epoch 21/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3536 - accuracy: 0.8531 - val_loss: 0.3398 - val_accuracy: 0.8662
# Epoch 22/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3511 - accuracy: 0.8564 - val_loss: 0.3404 - val_accuracy: 0.8681
# Epoch 23/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3468 - accuracy: 0.8584 - val_loss: 0.3389 - val_accuracy: 0.8669
# Epoch 24/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3468 - accuracy: 0.8602 - val_loss: 0.3413 - val_accuracy: 0.8706
# Epoch 25/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3463 - accuracy: 0.8581 - val_loss: 0.3370 - val_accuracy: 0.8644
# Epoch 26/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3482 - accuracy: 0.8525 - val_loss: 0.3441 - val_accuracy: 0.8669
# Epoch 27/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3446 - accuracy: 0.8622 - val_loss: 0.3367 - val_accuracy: 0.8725
# Epoch 28/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3434 - accuracy: 0.8614 - val_loss: 0.3365 - val_accuracy: 0.8700
# Epoch 29/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3419 - accuracy: 0.8598 - val_loss: 0.3457 - val_accuracy: 0.8631
# Epoch 30/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3375 - accuracy: 0.8592 - val_loss: 0.3366 - val_accuracy: 0.8662
# Epoch 31/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3415 - accuracy: 0.8606 - val_loss: 0.3377 - val_accuracy: 0.8706
# Epoch 32/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3431 - accuracy: 0.8583 - val_loss: 0.3385 - val_accuracy: 0.8656
# Epoch 33/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3389 - accuracy: 0.8600 - val_loss: 0.3405 - val_accuracy: 0.8662
# Epoch 34/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3358 - accuracy: 0.8600 - val_loss: 0.3375 - val_accuracy: 0.8681
# Epoch 35/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3368 - accuracy: 0.8616 - val_loss: 0.3366 - val_accuracy: 0.8681
# Epoch 36/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3357 - accuracy: 0.8622 - val_loss: 0.3376 - val_accuracy: 0.8600
# Epoch 37/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3326 - accuracy: 0.8622 - val_loss: 0.3374 - val_accuracy: 0.8706
# Epoch 38/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3337 - accuracy: 0.8598 - val_loss: 0.3354 - val_accuracy: 0.8669
# Epoch 39/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3305 - accuracy: 0.8661 - val_loss: 0.3367 - val_accuracy: 0.8737
# Epoch 40/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3310 - accuracy: 0.8648 - val_loss: 0.3352 - val_accuracy: 0.8694
# Epoch 41/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3302 - accuracy: 0.8602 - val_loss: 0.3382 - val_accuracy: 0.8675
# Epoch 42/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3307 - accuracy: 0.8634 - val_loss: 0.3351 - val_accuracy: 0.8675
# Epoch 43/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3323 - accuracy: 0.8612 - val_loss: 0.3416 - val_accuracy: 0.8619
# Epoch 44/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3271 - accuracy: 0.8650 - val_loss: 0.3413 - val_accuracy: 0.8662
# Epoch 45/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3247 - accuracy: 0.8653 - val_loss: 0.3382 - val_accuracy: 0.8719
# Epoch 46/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3250 - accuracy: 0.8655 - val_loss: 0.3418 - val_accuracy: 0.8700
# Epoch 47/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3288 - accuracy: 0.8648 - val_loss: 0.3417 - val_accuracy: 0.8662
# Epoch 48/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3257 - accuracy: 0.8683 - val_loss: 0.3393 - val_accuracy: 0.8687
# Epoch 49/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3254 - accuracy: 0.8656 - val_loss: 0.3410 - val_accuracy: 0.8712
# Epoch 50/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3243 - accuracy: 0.8675 - val_loss: 0.3401 - val_accuracy: 0.8669

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that both the curves train and validation are smoother and not over-fitted like in the previous model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat4 = model4.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat4 = yhat4[:, 0]
# calculate roc curves
fpr, tpr, thresholds4 = roc_curve(y_test, yhat4)
# calculate the g-mean for each threshold
gmeans4 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans4)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds4[ix], gmeans4[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.221197, G-Mean=0.762

# %%
y_pred_e4=model4.predict(X_test_normalized_df)
y_pred_e4 = (y_pred_e4 > thresholds4[ix])
y_pred_e4
# Out:
# 63/63 [==============================] - 0s 3ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm4=confusion_matrix(y_test, y_pred_e4)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm4, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr4=metrics.classification_report(y_test,y_pred_e4)
print(cr4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      1593
#            1       0.51      0.70      0.59       407
#
#     accuracy                           0.80      2000
#    macro avg       0.71      0.76      0.73      2000
# weighted avg       0.83      0.80      0.81      2000

# %% [markdown]
# The Dropout technique helped the model reduce the loss function of both train and validation. The recall score also seems to be fine, with a decrease in the False Negative rate.
#
# Now, let's try to use some of the Hyperparameter Optimization techniques we have learnt, such as RandomizedSearchCV, GridSearchCV and Keras Tuner to increase the recall score of the model.

# %% [markdown]
# ### Model 5

# %% [markdown]
# #### Random Search CV

# %% [markdown]
# Some important hyperparameters to look out for while optimizing neural networks are:
#
# - Type of Architecture
#
# - Number of Layers
#
# - Number of Neurons in a layer
#
# - Regularization hyperparameters
#
# - Learning Rate
#
# - Type of Optimizer
#
# - Dropout Rate

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v4(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v4, verbose=1)
# define the grid search parameters
param_random = {
    'batch_size':[32, 64, 128],
    "lr":[0.01,0.1,0.001],}

kfold_splits = 3
random= RandomizedSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_distributions=param_random,n_jobs=-1)

# %%
random_result = random.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (random_result.best_score_, random_result.best_params_))
means = random_result.cv_results_['mean_test_score']
stds = random_result.cv_results_['std_test_score']
params = random_result.cv_results_['params']
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 200/200 [==============================] - 2s 7ms/step - loss: 0.4782 - accuracy: 0.7970 - val_loss: 0.4571 - val_accuracy: 0.8000
# Best: 0.796250 using {'lr': 0.01, 'batch_size': 32}

# %%
estimator_v4=create_model_v4(batch_size=random_result.best_params_['batch_size'],lr=random_result.best_params_['lr'])

estimator_v4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2816
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(random_result.best_params_['lr'])
estimator_v4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_4=estimator_v4.fit(X_train_normalized_df, y_train, epochs=50, batch_size = 64, verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 9ms/step - loss: 0.4757 - accuracy: 0.7948 - val_loss: 0.4889 - val_accuracy: 0.8000
# Epoch 2/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4429 - accuracy: 0.8059 - val_loss: 0.4049 - val_accuracy: 0.8456
# Epoch 3/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4085 - accuracy: 0.8311 - val_loss: 0.3931 - val_accuracy: 0.8537
# Epoch 4/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3971 - accuracy: 0.8384 - val_loss: 0.3594 - val_accuracy: 0.8669
# Epoch 5/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3961 - accuracy: 0.8394 - val_loss: 0.3572 - val_accuracy: 0.8644
# Epoch 6/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3898 - accuracy: 0.8373 - val_loss: 0.3480 - val_accuracy: 0.8675
# Epoch 7/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3851 - accuracy: 0.8395 - val_loss: 0.3629 - val_accuracy: 0.8637
# Epoch 8/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3861 - accuracy: 0.8413 - val_loss: 0.3572 - val_accuracy: 0.8587
# Epoch 9/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3806 - accuracy: 0.8456 - val_loss: 0.3576 - val_accuracy: 0.8650
# Epoch 10/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3831 - accuracy: 0.8494 - val_loss: 0.3578 - val_accuracy: 0.8606
# Epoch 11/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3812 - accuracy: 0.8438 - val_loss: 0.3580 - val_accuracy: 0.8606
# Epoch 12/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3787 - accuracy: 0.8436 - val_loss: 0.3484 - val_accuracy: 0.8637
# Epoch 13/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3825 - accuracy: 0.8447 - val_loss: 0.3599 - val_accuracy: 0.8612
# Epoch 14/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3796 - accuracy: 0.8486 - val_loss: 0.3697 - val_accuracy: 0.8606
# Epoch 15/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3833 - accuracy: 0.8467 - val_loss: 0.3464 - val_accuracy: 0.8700
# Epoch 16/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3736 - accuracy: 0.8478 - val_loss: 0.3548 - val_accuracy: 0.8625
# Epoch 17/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.3740 - accuracy: 0.8473 - val_loss: 0.3494 - val_accuracy: 0.8650
# Epoch 18/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3770 - accuracy: 0.8453 - val_loss: 0.3492 - val_accuracy: 0.8650
# Epoch 19/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3731 - accuracy: 0.8458 - val_loss: 0.3457 - val_accuracy: 0.8644
# Epoch 20/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3749 - accuracy: 0.8484 - val_loss: 0.3523 - val_accuracy: 0.8612
# Epoch 21/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3808 - accuracy: 0.8459 - val_loss: 0.3499 - val_accuracy: 0.8650
# Epoch 22/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3758 - accuracy: 0.8461 - val_loss: 0.3439 - val_accuracy: 0.8675
# Epoch 23/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3750 - accuracy: 0.8462 - val_loss: 0.3546 - val_accuracy: 0.8619
# Epoch 24/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3784 - accuracy: 0.8469 - val_loss: 0.3549 - val_accuracy: 0.8669
# Epoch 25/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3753 - accuracy: 0.8475 - val_loss: 0.3539 - val_accuracy: 0.8687
# Epoch 26/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3752 - accuracy: 0.8445 - val_loss: 0.3568 - val_accuracy: 0.8631
# Epoch 27/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3738 - accuracy: 0.8477 - val_loss: 0.3509 - val_accuracy: 0.8687
# Epoch 28/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3698 - accuracy: 0.8484 - val_loss: 0.3435 - val_accuracy: 0.8694
# Epoch 29/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3667 - accuracy: 0.8520 - val_loss: 0.3542 - val_accuracy: 0.8662
# Epoch 30/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3648 - accuracy: 0.8500 - val_loss: 0.3494 - val_accuracy: 0.8619
# Epoch 31/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3633 - accuracy: 0.8498 - val_loss: 0.3444 - val_accuracy: 0.8644
# Epoch 32/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3711 - accuracy: 0.8466 - val_loss: 0.3464 - val_accuracy: 0.8637
# Epoch 33/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3727 - accuracy: 0.8470 - val_loss: 0.3505 - val_accuracy: 0.8644
# Epoch 34/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3734 - accuracy: 0.8470 - val_loss: 0.3486 - val_accuracy: 0.8625
# Epoch 35/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3657 - accuracy: 0.8503 - val_loss: 0.3513 - val_accuracy: 0.8694
# Epoch 36/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3702 - accuracy: 0.8472 - val_loss: 0.3411 - val_accuracy: 0.8606
# Epoch 37/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3695 - accuracy: 0.8497 - val_loss: 0.3407 - val_accuracy: 0.8650
# Epoch 38/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3735 - accuracy: 0.8467 - val_loss: 0.3489 - val_accuracy: 0.8669
# Epoch 39/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3653 - accuracy: 0.8508 - val_loss: 0.3508 - val_accuracy: 0.8662
# Epoch 40/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3696 - accuracy: 0.8475 - val_loss: 0.3497 - val_accuracy: 0.8569
# Epoch 41/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3719 - accuracy: 0.8467 - val_loss: 0.3572 - val_accuracy: 0.8650
# Epoch 42/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3704 - accuracy: 0.8478 - val_loss: 0.3407 - val_accuracy: 0.8675
# Epoch 43/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.8480 - val_loss: 0.3437 - val_accuracy: 0.8681
# Epoch 44/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3699 - accuracy: 0.8494 - val_loss: 0.3488 - val_accuracy: 0.8650
# Epoch 45/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8492 - val_loss: 0.3396 - val_accuracy: 0.8669
# Epoch 46/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3660 - accuracy: 0.8466 - val_loss: 0.3503 - val_accuracy: 0.8631
# Epoch 47/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3672 - accuracy: 0.8517 - val_loss: 0.3494 - val_accuracy: 0.8631
# Epoch 48/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3644 - accuracy: 0.8489 - val_loss: 0.3469 - val_accuracy: 0.8644
# Epoch 49/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3660 - accuracy: 0.8508 - val_loss: 0.3467 - val_accuracy: 0.8700
# Epoch 50/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3665 - accuracy: 0.8494 - val_loss: 0.3403 - val_accuracy: 0.8687

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that there is noise in the both training and validation behavior of the model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat4 = estimator_v4.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat4 = yhat4[:, 0]
# calculate roc curves
fpr, tpr, thresholds4 = roc_curve(y_test, yhat4)
# calculate the g-mean for each threshold
gmeans4 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans4)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds4[ix], gmeans4[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.216967, G-Mean=0.763

# %%
y_pred_e4=estimator_v4.predict(X_test_normalized_df)
y_pred_e4 = (y_pred_e4 > thresholds4[ix])
y_pred_e4
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm4=confusion_matrix(y_test, y_pred_e4)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm4, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr4=metrics.classification_report(y_test,y_pred_e4)
print(cr4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1593
#            1       0.49      0.71      0.58       407
#
#     accuracy                           0.79      2000
#    macro avg       0.71      0.76      0.72      2000
# weighted avg       0.83      0.79      0.81      2000

# %% [markdown]
# Hyperparameter tuning with Grid Search has been used here to get a better recall score, but the recall score might differ each time.
#
# Other hyperparameters can also be tuned to get better metrics.
#
# Here, the recall score of the model, while better than in Randomized Search, is slightly lower than in Model 1 (the simple model).

# %% [markdown]
# ### Model 6

# %% [markdown]
# #### Grid Search CV

# %% [markdown]
# Some important hyperparameters to look out for while optimizing neural networks are:
#
# - Type of Architecture
#
# - Number of Layers
#
# - Number of Neurons in a layer
#
# - Regularization hyperparameters
#
# - Learning Rate
#
# - Type of Optimizer
#
# - Dropout Rate

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v5(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %% [markdown]
# We're using Grid Search to optimize two hyperparameters - Batch Size & Learning Rate.
#
# We can also optimize the other hyperparameters as mentioned above.

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v5, verbose=1)
# define the grid search parameters
param_grid = {
    'batch_size':[64,32, 128],
    "lr":[0.01,0.1,0.001],}

kfold_splits = 3
grid = GridSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)

# %%
import time
  
# store starting time
begin = time.time()


grid_result = grid.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

time.sleep(1)
# store end time
end = time.time()
  
# total time taken
print(f"Total runtime of the program is {end - begin}")
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 200/200 [==============================] - 2s 5ms/step - loss: 0.4782 - accuracy: 0.7970 - val_loss: 0.4571 - val_accuracy: 0.8000
# Best: 0.796375 using {'batch_size': 32, 'lr': 0.01}
# Total runtime of the program is 26.866636991500854

# %% [markdown]
# The best model has the following configuration:
#
# ( It may vary each time the code runs )

# %%
estimator_v5=create_model_v5(batch_size=grid_result.best_params_['batch_size'],lr=grid_result.best_params_['lr'])

estimator_v5.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2816
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(grid_result.best_params_['lr'])
estimator_v5.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_5=estimator_v5.fit(X_train_normalized_df, y_train, epochs=50, batch_size = 64, verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 3s 7ms/step - loss: 0.4757 - accuracy: 0.7948 - val_loss: 0.4889 - val_accuracy: 0.8000
# Epoch 2/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4429 - accuracy: 0.8059 - val_loss: 0.4049 - val_accuracy: 0.8456
# Epoch 3/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4085 - accuracy: 0.8311 - val_loss: 0.3931 - val_accuracy: 0.8537
# Epoch 4/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3971 - accuracy: 0.8384 - val_loss: 0.3594 - val_accuracy: 0.8669
# Epoch 5/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3961 - accuracy: 0.8394 - val_loss: 0.3572 - val_accuracy: 0.8644
# Epoch 6/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3898 - accuracy: 0.8373 - val_loss: 0.3480 - val_accuracy: 0.8675
# Epoch 7/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3851 - accuracy: 0.8395 - val_loss: 0.3629 - val_accuracy: 0.8637
# Epoch 8/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3861 - accuracy: 0.8413 - val_loss: 0.3572 - val_accuracy: 0.8587
# Epoch 9/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3806 - accuracy: 0.8456 - val_loss: 0.3576 - val_accuracy: 0.8650
# Epoch 10/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3831 - accuracy: 0.8494 - val_loss: 0.3578 - val_accuracy: 0.8606
# Epoch 11/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3812 - accuracy: 0.8438 - val_loss: 0.3580 - val_accuracy: 0.8606
# Epoch 12/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3787 - accuracy: 0.8436 - val_loss: 0.3484 - val_accuracy: 0.8637
# Epoch 13/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3825 - accuracy: 0.8447 - val_loss: 0.3599 - val_accuracy: 0.8612
# Epoch 14/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3796 - accuracy: 0.8486 - val_loss: 0.3697 - val_accuracy: 0.8606
# Epoch 15/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3833 - accuracy: 0.8467 - val_loss: 0.3464 - val_accuracy: 0.8700
# Epoch 16/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3736 - accuracy: 0.8478 - val_loss: 0.3548 - val_accuracy: 0.8625
# Epoch 17/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3740 - accuracy: 0.8473 - val_loss: 0.3494 - val_accuracy: 0.8650
# Epoch 18/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3770 - accuracy: 0.8453 - val_loss: 0.3492 - val_accuracy: 0.8650
# Epoch 19/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3731 - accuracy: 0.8458 - val_loss: 0.3457 - val_accuracy: 0.8644
# Epoch 20/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3749 - accuracy: 0.8484 - val_loss: 0.3523 - val_accuracy: 0.8612
# Epoch 21/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3808 - accuracy: 0.8459 - val_loss: 0.3499 - val_accuracy: 0.8650
# Epoch 22/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3758 - accuracy: 0.8461 - val_loss: 0.3439 - val_accuracy: 0.8675
# Epoch 23/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3750 - accuracy: 0.8462 - val_loss: 0.3546 - val_accuracy: 0.8619
# Epoch 24/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3784 - accuracy: 0.8469 - val_loss: 0.3549 - val_accuracy: 0.8669
# Epoch 25/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3753 - accuracy: 0.8475 - val_loss: 0.3539 - val_accuracy: 0.8687
# Epoch 26/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3752 - accuracy: 0.8445 - val_loss: 0.3568 - val_accuracy: 0.8631
# Epoch 27/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3738 - accuracy: 0.8477 - val_loss: 0.3509 - val_accuracy: 0.8687
# Epoch 28/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8484 - val_loss: 0.3435 - val_accuracy: 0.8694
# Epoch 29/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3667 - accuracy: 0.8520 - val_loss: 0.3542 - val_accuracy: 0.8662
# Epoch 30/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3648 - accuracy: 0.8500 - val_loss: 0.3494 - val_accuracy: 0.8619
# Epoch 31/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3633 - accuracy: 0.8498 - val_loss: 0.3444 - val_accuracy: 0.8644
# Epoch 32/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3711 - accuracy: 0.8466 - val_loss: 0.3464 - val_accuracy: 0.8637
# Epoch 33/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3727 - accuracy: 0.8470 - val_loss: 0.3505 - val_accuracy: 0.8644
# Epoch 34/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3734 - accuracy: 0.8470 - val_loss: 0.3486 - val_accuracy: 0.8625
# Epoch 35/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3657 - accuracy: 0.8503 - val_loss: 0.3513 - val_accuracy: 0.8694
# Epoch 36/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3702 - accuracy: 0.8472 - val_loss: 0.3411 - val_accuracy: 0.8606
# Epoch 37/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3695 - accuracy: 0.8497 - val_loss: 0.3407 - val_accuracy: 0.8650
# Epoch 38/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3735 - accuracy: 0.8467 - val_loss: 0.3489 - val_accuracy: 0.8669
# Epoch 39/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3653 - accuracy: 0.8508 - val_loss: 0.3508 - val_accuracy: 0.8662
# Epoch 40/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3696 - accuracy: 0.8475 - val_loss: 0.3497 - val_accuracy: 0.8569
# Epoch 41/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3719 - accuracy: 0.8467 - val_loss: 0.3572 - val_accuracy: 0.8650
# Epoch 42/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3704 - accuracy: 0.8478 - val_loss: 0.3407 - val_accuracy: 0.8675
# Epoch 43/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3696 - accuracy: 0.8480 - val_loss: 0.3437 - val_accuracy: 0.8681
# Epoch 44/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3699 - accuracy: 0.8494 - val_loss: 0.3488 - val_accuracy: 0.8650
# Epoch 45/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3654 - accuracy: 0.8492 - val_loss: 0.3396 - val_accuracy: 0.8669
# Epoch 46/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3660 - accuracy: 0.8466 - val_loss: 0.3503 - val_accuracy: 0.8631
# Epoch 47/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3672 - accuracy: 0.8517 - val_loss: 0.3494 - val_accuracy: 0.8631
# Epoch 48/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3644 - accuracy: 0.8489 - val_loss: 0.3469 - val_accuracy: 0.8644
# Epoch 49/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3660 - accuracy: 0.8508 - val_loss: 0.3467 - val_accuracy: 0.8700
# Epoch 50/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3665 - accuracy: 0.8494 - val_loss: 0.3403 - val_accuracy: 0.8687

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that both curves - train and validation, are relatively smooth.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat5 = estimator_v5.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat5 = yhat5[:, 0]
# calculate roc curves
fpr, tpr, thresholds5 = roc_curve(y_test, yhat5)
# calculate the g-mean for each threshold
gmeans5 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans5)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds5[ix], gmeans5[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 3ms/step
# Best Threshold=0.216967, G-Mean=0.763

# %%
y_pred_e5=estimator_v5.predict(X_test_normalized_df)
y_pred_e5 = (y_pred_e5 > thresholds5[ix])
y_pred_e5
# Out:
# 63/63 [==============================] - 0s 3ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm5=confusion_matrix(y_test, y_pred_e5)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm5, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr6=metrics.classification_report(y_test,y_pred_e5)
print(cr6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1593
#            1       0.49      0.71      0.58       407
#
#     accuracy                           0.79      2000
#    macro avg       0.71      0.76      0.72      2000
# weighted avg       0.83      0.79      0.81      2000

# %% [markdown]
# Hyperparameter tuning with Grid Search has been used here to get a better recall score, but the recall score might differ each time.
#
# Other hyperparameters can also be tuned to get better metrics.
#
# Here, the recall score of the model is better than the Randomized search but it is still less better than our Model 4 which used Dropout technique.

# %% [markdown]
# ### DASK

# %% [markdown]
# - There is also another library called Dask, sometimes used in the industry to provide a performance boost to Hyperparameter Tuning due to its parallelized computing procedure.
# - Dask also has the option of implementing Grid Search similar to the Grid Search in Scikit-learn.

# %%
# importing library
from dask_ml.model_selection import GridSearchCV as DaskGridSearchCV

# %%
def create_model_v6(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v6, verbose=1)
# define the grid search parameters
param_grid = {
    'batch_size':[64,32, 128],
    "lr":[0.001,0.01,0.1],}

kfold_splits = 3
dask = DaskGridSearchCV(estimator=keras_estimator, 
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)

# %%
import time
  
# store starting time
begin = time.time()


dask_result = dask.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (dask_result.best_score_, dask_result.best_params_))
means = dask_result.cv_results_['mean_test_score']
stds = dask_result.cv_results_['std_test_score']
params = dask_result.cv_results_['params']

time.sleep(1)
# store end time
end = time.time()
  
# total time taken
print(f"Total runtime of the program is {end - begin}")
# Out:
# 67/67 [==============================] - 6s 25ms/step - loss: 0.5109 - accuracy: 0.7980 - val_loss: 0.4894 - val_accuracy: 0.7844
# 67/67 [==============================] - 6s 28ms/step - loss: 0.5207 - accuracy: 0.7738 - val_loss: 0.4693 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s 24ms/step - loss: 0.4810 - accuracy: 0.7926
# 67/67 [==============================] - 7s 42ms/step - loss: 0.4919 - accuracy: 0.7909 - val_loss: 0.4523 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s 23ms/step - loss: 0.4583 - accuracy: 0.8076
# 67/67 [==============================] - 8s 46ms/step - loss: 0.5063 - accuracy: 0.7965 - val_loss: 0.4699 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s 22ms/step - loss: 0.4584 - accuracy: 0.7885
# 42/42 [==============================] - 1s 23ms/step - loss: 0.4807 - accuracy: 0.7885
# 67/67 [==============================] - 6s 38ms/step - loss: 0.4939 - accuracy: 0.7865 - val_loss: 0.5223 - val_accuracy: 0.8032
# 67/67 [==============================] - 7s 35ms/step - loss: 0.4915 - accuracy: 0.7940 - val_loss: 0.4909 - val_accuracy: 0.7844
# 42/42 [==============================] - 1s 16ms/step - loss: 0.4854 - accuracy: 0.8076
# 67/67 [==============================] - 7s 39ms/step - loss: 1.6908 - accuracy: 0.7986 - val_loss: 0.4962 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s 21ms/step - loss: 0.4858 - accuracy: 0.7926
# 67/67 [==============================] - 7s 41ms/step - loss: 1.2685 - accuracy: 0.7747 - val_loss: 0.4979 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s 25ms/step - loss: 0.5160 - accuracy: 0.7885
# 42/42 [==============================] - 1s 24ms/step - loss: 0.4923 - accuracy: 0.8076
# 67/67 [==============================] - 7s 42ms/step - loss: 0.8564 - accuracy: 0.7949 - val_loss: 0.5229 - val_accuracy: 0.7844
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5112 - accuracy: 0.7926
# 134/134 [==============================] - 8s 28ms/step - loss: 0.4968 - accuracy: 0.7986 - val_loss: 0.4649 - val_accuracy: 0.8032
# 134/134 [==============================] - 7s 23ms/step - loss: 0.5030 - accuracy: 0.7850 - val_loss: 0.4682 - val_accuracy: 0.8032
# 134/134 [==============================] - 8s 26ms/step - loss: 0.4868 - accuracy: 0.7999 - val_loss: 0.4807 - val_accuracy: 0.7844
# 84/84 [==============================] - 2s 18ms/step - loss: 0.4772 - accuracy: 0.7885
# 84/84 [==============================] - 1s 16ms/step - loss: 0.4513 - accuracy: 0.8076
# 84/84 [==============================] - 2s 21ms/step - loss: 0.4738 - accuracy: 0.7926
# 134/134 [==============================] - 11s 48ms/step - loss: 0.4935 - accuracy: 0.7963 - val_loss: 0.4560 - val_accuracy: 0.8032
# 84/84 [==============================] - 1s 15ms/step - loss: 0.4671 - accuracy: 0.7885
# 134/134 [==============================] - 10s 24ms/step - loss: 0.5033 - accuracy: 0.7921 - val_loss: 0.4666 - val_accuracy: 0.8041
# 134/134 [==============================] - 10s 22ms/step - loss: 0.4802 - accuracy: 0.7980 - val_loss: 0.4618 - val_accuracy: 0.7844
# 84/84 [==============================] - 1s 16ms/step - loss: 0.4526 - accuracy: 0.8080
# 84/84 [==============================] - 2s 29ms/step - loss: 0.4556 - accuracy: 0.7926
# 134/134 [==============================] - 12s 43ms/step - loss: 0.7362 - accuracy: 0.7893 - val_loss: 0.4985 - val_accuracy: 0.8032
# 84/84 [==============================] - 6s 69ms/step - loss: 0.5218 - accuracy: 0.7885
# 134/134 [==============================] - 10s 28ms/step - loss: 0.6497 - accuracy: 0.7799 - val_loss: 0.4960 - val_accuracy: 0.8032
# 34/34 [==============================] - 7s 52ms/step - loss: 0.5391 - accuracy: 0.7700 - val_loss: 0.4860 - val_accuracy: 0.8032
# 84/84 [==============================] - 1s 13ms/step - loss: 0.4897 - accuracy: 0.8076
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4999 - accuracy: 0.7885
# 134/134 [==============================] - 9s 26ms/step - loss: 0.6010 - accuracy: 0.7949 - val_loss: 0.5255 - val_accuracy: 0.7844
# 84/84 [==============================] - 2s 18ms/step - loss: 0.5132 - accuracy: 0.7926
# 34/34 [==============================] - 6s 66ms/step - loss: 0.5423 - accuracy: 0.7726 - val_loss: 0.4887 - val_accuracy: 0.8032
# 21/21 [==============================] - 0s 21ms/step - loss: 0.4831 - accuracy: 0.8076
# 34/34 [==============================] - 6s 57ms/step - loss: 0.5163 - accuracy: 0.7982 - val_loss: 0.4922 - val_accuracy: 0.7844
# 21/21 [==============================] - 0s 12ms/step - loss: 0.4849 - accuracy: 0.7926
# 34/34 [==============================] - 7s 61ms/step - loss: 0.4952 - accuracy: 0.7989 - val_loss: 0.4615 - val_accuracy: 0.8032
# 21/21 [==============================] - 0s 13ms/step - loss: 0.4695 - accuracy: 0.7885
# 34/34 [==============================] - 6s 49ms/step - loss: 0.5052 - accuracy: 0.7707 - val_loss: 0.4844 - val_accuracy: 0.8032
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4599 - accuracy: 0.8076
# 34/34 [==============================] - 6s 55ms/step - loss: 0.5061 - accuracy: 0.7968 - val_loss: 0.4727 - val_accuracy: 0.7844
# 21/21 [==============================] - 0s 16ms/step - loss: 0.4678 - accuracy: 0.7926
# 34/34 [==============================] - 5s 43ms/step - loss: 2.8185 - accuracy: 0.7890 - val_loss: 0.5005 - val_accuracy: 0.8032
# 21/21 [==============================] - 0s 8ms/step - loss: 0.5248 - accuracy: 0.7885
# 34/34 [==============================] - 5s 29ms/step - loss: 2.0101 - accuracy: 0.7768 - val_loss: 0.4968 - val_accuracy: 0.8032
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4901 - accuracy: 0.8076
# 34/34 [==============================] - 4s 16ms/step - loss: 4.5651 - accuracy: 0.8010 - val_loss: 0.5319 - val_accuracy: 0.7844
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5184 - accuracy: 0.7926
# 200/200 [==============================] - 2s 5ms/step - loss: 0.4818 - accuracy: 0.7977 - val_loss: 0.4411 - val_accuracy: 0.8175
# Best: 0.796375 using {'batch_size': 32, 'lr': 0.01}
# Total runtime of the program is 68.73174142837524

# %% [markdown]
# - We can clearly see the Dask took longer than the Grid search CV.
# - Since the dataset dimensions and hyperparameter number/range were small for this example, Dask couldn't show a significant improvement.

# %% [markdown]
# ### Keras Tuner

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# #### Hyperparameters

# %% [markdown]
# - How many hidden layers should the model have?
# - How many neurons should the model have in each hidden layer?
# - Learning Rate

# %%
def build_model(h):
    model = keras.Sequential()
    for i in range(h.Int('num_layers', 2, 10)):
        model.add(layers.Dense(units=h.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=256,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            h.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %% [markdown]
# Initialize a tuner (here, RandomSearch)

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
     project_name='Job_')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\Job_\oracle.json
# INFO:tensorflow:Reloading Tuner from .\Job_\tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}

# %%
### Searching the best model on X and y train
tuner.search(X_train_normalized_df, y_train,
             epochs=5,
             validation_split = 0.2)
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
## Printing the best models with their hyperparameters
tuner.results_summary()
# Out:
# Results summary
# Results in .\Job_
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000002C4C4737C10>
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 160
# units_1: 160
# learning_rate: 0.001
# units_2: 224
# units_3: 128
# units_4: 224
# units_5: 64
# units_6: 160
# units_7: 64
# units_8: 32
# Score: 0.8727083206176758
# Trial summary
# Hyperparameters:
# num_layers: 8
# units_0: 160
# units_1: 64
# learning_rate: 0.001
# units_2: 160
# units_3: 64
# units_4: 192
# units_5: 32
# units_6: 224
# units_7: 96
# units_8: 192
# Score: 0.8702083428700765
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 64
# units_1: 96
# learning_rate: 0.001
# units_2: 96
# units_3: 224
# units_4: 256
# units_5: 160
# units_6: 192
# units_7: 224
# units_8: 224
# Score: 0.8687500158945719
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 128
# units_1: 32
# learning_rate: 0.0001
# units_2: 160
# units_3: 160
# units_4: 160
# units_5: 192
# units_6: 96
# units_7: 128
# units_8: 96
# Score: 0.8356250127156576
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 192
# units_1: 96
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# Score: 0.8289583325386047

# %% [markdown]
# Let's create a model with the above mentioned best configuration given by Keras Tuner.

# %% [markdown]
# ### Model 7

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model7 = Sequential()
model7.add(Dense(160,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model7.add(Dense(160,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(1, activation = 'sigmoid'))

# %%
model7.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 160)               1760
#
#  dense_1 (Dense)             (None, 160)               25760
#
#  dense_2 (Dense)             (None, 224)               36064
#
#  dense_3 (Dense)             (None, 128)               28800
#
#  dense_4 (Dense)             (None, 224)               28896
#
#  dense_5 (Dense)             (None, 1)                 225
#
# =================================================================
# Total params: 121,505
# Trainable params: 121,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model7.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_7 = model7.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4651 - accuracy: 0.8045 - val_loss: 0.4589 - val_accuracy: 0.8094
# Epoch 2/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4067 - accuracy: 0.8267 - val_loss: 0.3828 - val_accuracy: 0.8356
# Epoch 3/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3799 - accuracy: 0.8359 - val_loss: 0.3656 - val_accuracy: 0.8487
# Epoch 4/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3635 - accuracy: 0.8475 - val_loss: 0.3715 - val_accuracy: 0.8581
# Epoch 5/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3567 - accuracy: 0.8522 - val_loss: 0.3479 - val_accuracy: 0.8569
# Epoch 6/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3568 - accuracy: 0.8514 - val_loss: 0.3493 - val_accuracy: 0.8562
# Epoch 7/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3444 - accuracy: 0.8555 - val_loss: 0.3581 - val_accuracy: 0.8550
# Epoch 8/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3415 - accuracy: 0.8598 - val_loss: 0.3471 - val_accuracy: 0.8569
# Epoch 9/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3352 - accuracy: 0.8608 - val_loss: 0.3476 - val_accuracy: 0.8600
# Epoch 10/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3297 - accuracy: 0.8641 - val_loss: 0.3513 - val_accuracy: 0.8619
# Epoch 11/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3245 - accuracy: 0.8600 - val_loss: 0.3571 - val_accuracy: 0.8650
# Epoch 12/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3236 - accuracy: 0.8652 - val_loss: 0.3557 - val_accuracy: 0.8631
# Epoch 13/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3177 - accuracy: 0.8700 - val_loss: 0.3669 - val_accuracy: 0.8537
# Epoch 14/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3142 - accuracy: 0.8712 - val_loss: 0.3583 - val_accuracy: 0.8631
# Epoch 15/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3018 - accuracy: 0.8770 - val_loss: 0.3658 - val_accuracy: 0.8569
# Epoch 16/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3034 - accuracy: 0.8714 - val_loss: 0.3938 - val_accuracy: 0.8456
# Epoch 17/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.8761 - val_loss: 0.3831 - val_accuracy: 0.8537
# Epoch 18/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2927 - accuracy: 0.8753 - val_loss: 0.3715 - val_accuracy: 0.8581
# Epoch 19/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2853 - accuracy: 0.8798 - val_loss: 0.3782 - val_accuracy: 0.8581
# Epoch 20/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2813 - accuracy: 0.8844 - val_loss: 0.3995 - val_accuracy: 0.8506
# Epoch 21/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2742 - accuracy: 0.8848 - val_loss: 0.3866 - val_accuracy: 0.8531
# Epoch 22/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2698 - accuracy: 0.8872 - val_loss: 0.4103 - val_accuracy: 0.8506
# Epoch 23/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2617 - accuracy: 0.8881 - val_loss: 0.3989 - val_accuracy: 0.8587
# Epoch 24/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2594 - accuracy: 0.8905 - val_loss: 0.4091 - val_accuracy: 0.8550
# Epoch 25/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2490 - accuracy: 0.8923 - val_loss: 0.4326 - val_accuracy: 0.8519
# Epoch 26/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2474 - accuracy: 0.8936 - val_loss: 0.4401 - val_accuracy: 0.8531
# Epoch 27/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2367 - accuracy: 0.9005 - val_loss: 0.4550 - val_accuracy: 0.8388
# Epoch 28/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2389 - accuracy: 0.8963 - val_loss: 0.4445 - val_accuracy: 0.8450
# Epoch 29/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2306 - accuracy: 0.9022 - val_loss: 0.4641 - val_accuracy: 0.8500
# Epoch 30/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2179 - accuracy: 0.9047 - val_loss: 0.4784 - val_accuracy: 0.8531
# Epoch 31/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2169 - accuracy: 0.9080 - val_loss: 0.4846 - val_accuracy: 0.8413
# Epoch 32/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2076 - accuracy: 0.9084 - val_loss: 0.5167 - val_accuracy: 0.8413
# Epoch 33/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1987 - accuracy: 0.9134 - val_loss: 0.5623 - val_accuracy: 0.8425
# Epoch 34/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2008 - accuracy: 0.9137 - val_loss: 0.5067 - val_accuracy: 0.8344
# Epoch 35/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1988 - accuracy: 0.9139 - val_loss: 0.5489 - val_accuracy: 0.8369
# Epoch 36/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1821 - accuracy: 0.9191 - val_loss: 0.5874 - val_accuracy: 0.8419
# Epoch 37/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1802 - accuracy: 0.9200 - val_loss: 0.5475 - val_accuracy: 0.8344
# Epoch 38/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1777 - accuracy: 0.9262 - val_loss: 0.5984 - val_accuracy: 0.8413
# Epoch 39/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1743 - accuracy: 0.9222 - val_loss: 0.6143 - val_accuracy: 0.8331
# Epoch 40/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1758 - accuracy: 0.9237 - val_loss: 0.6106 - val_accuracy: 0.8275
# Epoch 41/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1511 - accuracy: 0.9330 - val_loss: 0.6627 - val_accuracy: 0.8281
# Epoch 42/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1492 - accuracy: 0.9353 - val_loss: 0.7708 - val_accuracy: 0.8231
# Epoch 43/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1522 - accuracy: 0.9325 - val_loss: 0.7518 - val_accuracy: 0.8394
# Epoch 44/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1354 - accuracy: 0.9409 - val_loss: 0.7520 - val_accuracy: 0.8269
# Epoch 45/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1262 - accuracy: 0.9445 - val_loss: 0.7892 - val_accuracy: 0.8325
# Epoch 46/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1191 - accuracy: 0.9491 - val_loss: 0.8200 - val_accuracy: 0.8219
# Epoch 47/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1337 - accuracy: 0.9450 - val_loss: 0.8301 - val_accuracy: 0.8294
# Epoch 48/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1303 - accuracy: 0.9452 - val_loss: 0.9230 - val_accuracy: 0.8062
# Epoch 49/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1277 - accuracy: 0.9472 - val_loss: 0.8412 - val_accuracy: 0.8281
# Epoch 50/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1108 - accuracy: 0.9522 - val_loss: 0.8541 - val_accuracy: 0.8163

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_7.history['loss'])
plt.plot(history_7.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that the train and validation curves show overfitted model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat7 = model7.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat7 = yhat7[:, 0]
# calculate roc curves
fpr, tpr, thresholds7 = roc_curve(y_test, yhat7)
# calculate the g-mean for each threshold
gmeans7 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans7)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds7[ix], gmeans7[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 3ms/step
# Best Threshold=0.082475, G-Mean=0.710

# %%
y_pred_e7=model7.predict(X_test_normalized_df)
y_pred_e7 = (y_pred_e7 > thresholds7[ix])
y_pred_e7
# Out:
# 63/63 [==============================] - 0s 3ms/step
# array([[False],
#        [False],
#        [ True],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm7=confusion_matrix(y_test, y_pred_e7)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm7, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr7=metrics.classification_report(y_test,y_pred_e7)
print(cr7)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1593
#            1       0.41      0.67      0.51       407
#
#     accuracy                           0.73      2000
#    macro avg       0.65      0.71      0.66      2000
# weighted avg       0.80      0.73      0.76      2000

# %% [markdown]
# After using the suggested hyperparameters from Keras Tuner, the recall score and the False Negative rate have improved overall but still less than our best optimized model with Grid search CV so far.

# %% [markdown]
# ### SMOTE + Keras Tuner

# %%
##Applying SMOTE on train and test
from imblearn.over_sampling import SMOTE
smote=SMOTE(sampling_strategy='not majority')
X_sm , y_sm = smote.fit_resample(X_train_normalized_df,y_train)

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def build_model_2(h):
    model = keras.Sequential()
    for i in range(h.Int('num_layers', 2, 10)):
        model.add(layers.Dense(units=h.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=256,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            h.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner_2 = RandomSearch(
    build_model_2,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    project_name='Job_Switch')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\Job_Switch\oracle.json
# INFO:tensorflow:Reloading Tuner from .\Job_Switch\tuner0.json

# %%
tuner_2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 11
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}

# %%
tuner_2.search(X_sm, y_sm,
             epochs=5,
             validation_split = 0.2)
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner_2.results_summary()
# Out:
# Results summary
# Results in .\Job_Switch
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000002C4AA4DB6D0>
# Trial summary
# Hyperparameters:
# num_layers: 8
# units_0: 160
# units_1: 64
# learning_rate: 0.001
# units_2: 160
# units_3: 64
# units_4: 192
# units_5: 32
# units_6: 224
# units_7: 96
# units_8: 192
# Score: 0.7459445397059122
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 160
# units_1: 160
# learning_rate: 0.001
# units_2: 224
# units_3: 128
# units_4: 224
# units_5: 64
# units_6: 160
# units_7: 64
# units_8: 32
# Score: 0.7418890595436096
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 64
# units_1: 96
# learning_rate: 0.001
# units_2: 96
# units_3: 224
# units_4: 256
# units_5: 160
# units_6: 192
# units_7: 224
# units_8: 224
# Score: 0.7021193305651346
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 128
# units_1: 32
# learning_rate: 0.0001
# units_2: 160
# units_3: 160
# units_4: 160
# units_5: 192
# units_6: 96
# units_7: 128
# units_8: 96
# Score: 0.6225797931353251
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 192
# units_1: 96
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# Score: 0.6134222745895386

# %%
model9 = Sequential()
model9.add(Dense(160,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model9.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(160,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(192,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(96,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(1, activation = 'sigmoid'))
      #Compiling the ANN with Adam optimizer and binary cross entropy loss function 
optimizer = tf.keras.optimizers.Adam(0.001)
model9.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_9 = model9.fit(X_sm,y_sm,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 160/160 [==============================] - 3s 9ms/step - loss: 0.5761 - accuracy: 0.6994 - val_loss: 0.5585 - val_accuracy: 0.6476
# Epoch 2/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.4909 - accuracy: 0.7552 - val_loss: 1.1609 - val_accuracy: 0.2276
# Epoch 3/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4624 - accuracy: 0.7776 - val_loss: 0.6095 - val_accuracy: 0.6868
# Epoch 4/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4361 - accuracy: 0.7940 - val_loss: 0.5200 - val_accuracy: 0.7469
# Epoch 5/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4225 - accuracy: 0.8016 - val_loss: 0.7120 - val_accuracy: 0.6209
# Epoch 6/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4190 - accuracy: 0.8047 - val_loss: 0.5861 - val_accuracy: 0.7104
# Epoch 7/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4067 - accuracy: 0.8092 - val_loss: 0.7874 - val_accuracy: 0.6060
# Epoch 8/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4040 - accuracy: 0.8111 - val_loss: 0.5910 - val_accuracy: 0.7284
# Epoch 9/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3886 - accuracy: 0.8152 - val_loss: 0.5273 - val_accuracy: 0.7688
# Epoch 10/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3831 - accuracy: 0.8179 - val_loss: 0.6259 - val_accuracy: 0.6919
# Epoch 11/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3728 - accuracy: 0.8231 - val_loss: 0.3896 - val_accuracy: 0.8116
# Epoch 12/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3693 - accuracy: 0.8265 - val_loss: 0.6095 - val_accuracy: 0.7119
# Epoch 13/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3626 - accuracy: 0.8330 - val_loss: 0.4586 - val_accuracy: 0.7645
# Epoch 14/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3554 - accuracy: 0.8317 - val_loss: 0.5943 - val_accuracy: 0.6982
# Epoch 15/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3553 - accuracy: 0.8330 - val_loss: 0.4912 - val_accuracy: 0.7865
# Epoch 16/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3383 - accuracy: 0.8419 - val_loss: 0.4373 - val_accuracy: 0.8414
# Epoch 17/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.3366 - accuracy: 0.8432 - val_loss: 0.4624 - val_accuracy: 0.7724
# Epoch 18/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.3260 - accuracy: 0.8496 - val_loss: 0.4556 - val_accuracy: 0.7885
# Epoch 19/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.3194 - accuracy: 0.8551 - val_loss: 0.4845 - val_accuracy: 0.7877
# Epoch 20/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.3097 - accuracy: 0.8582 - val_loss: 0.4544 - val_accuracy: 0.8085
# Epoch 21/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.3083 - accuracy: 0.8564 - val_loss: 0.5624 - val_accuracy: 0.7339
# Epoch 22/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.3015 - accuracy: 0.8610 - val_loss: 0.4567 - val_accuracy: 0.8065
# Epoch 23/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2946 - accuracy: 0.8680 - val_loss: 0.3613 - val_accuracy: 0.8662
# Epoch 24/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2843 - accuracy: 0.8737 - val_loss: 0.4740 - val_accuracy: 0.7904
# Epoch 25/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2781 - accuracy: 0.8734 - val_loss: 0.3536 - val_accuracy: 0.8516
# Epoch 26/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.2712 - accuracy: 0.8788 - val_loss: 0.3528 - val_accuracy: 0.8599
# Epoch 27/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2669 - accuracy: 0.8791 - val_loss: 0.3910 - val_accuracy: 0.8250
# Epoch 28/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2559 - accuracy: 0.8888 - val_loss: 0.3779 - val_accuracy: 0.8387
# Epoch 29/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2465 - accuracy: 0.8917 - val_loss: 0.3403 - val_accuracy: 0.8560
# Epoch 30/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2383 - accuracy: 0.8965 - val_loss: 0.2572 - val_accuracy: 0.9070
# Epoch 31/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.2347 - accuracy: 0.8956 - val_loss: 0.4389 - val_accuracy: 0.7861
# Epoch 32/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.2276 - accuracy: 0.8976 - val_loss: 0.2952 - val_accuracy: 0.8889
# Epoch 33/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2254 - accuracy: 0.9031 - val_loss: 0.3131 - val_accuracy: 0.8846
# Epoch 34/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2103 - accuracy: 0.9101 - val_loss: 0.3719 - val_accuracy: 0.8516
# Epoch 35/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2153 - accuracy: 0.9041 - val_loss: 0.3121 - val_accuracy: 0.8713
# Epoch 36/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1983 - accuracy: 0.9152 - val_loss: 0.2954 - val_accuracy: 0.9015
# Epoch 37/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1984 - accuracy: 0.9124 - val_loss: 0.3086 - val_accuracy: 0.8768
# Epoch 38/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1955 - accuracy: 0.9166 - val_loss: 0.1866 - val_accuracy: 0.9427
# Epoch 39/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1952 - accuracy: 0.9155 - val_loss: 0.2929 - val_accuracy: 0.8799
# Epoch 40/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1783 - accuracy: 0.9215 - val_loss: 0.3440 - val_accuracy: 0.8705
# Epoch 41/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.1843 - accuracy: 0.9240 - val_loss: 0.3620 - val_accuracy: 0.8548
# Epoch 42/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.1726 - accuracy: 0.9247 - val_loss: 0.4362 - val_accuracy: 0.8218
# Epoch 43/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1663 - accuracy: 0.9281 - val_loss: 0.3231 - val_accuracy: 0.8870
# Epoch 44/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1644 - accuracy: 0.9297 - val_loss: 0.2903 - val_accuracy: 0.9019
# Epoch 45/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1640 - accuracy: 0.9323 - val_loss: 0.3537 - val_accuracy: 0.8595
# Epoch 46/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1525 - accuracy: 0.9375 - val_loss: 0.4063 - val_accuracy: 0.8332
# Epoch 47/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1596 - accuracy: 0.9322 - val_loss: 0.2594 - val_accuracy: 0.8987
# Epoch 48/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1429 - accuracy: 0.9411 - val_loss: 0.3983 - val_accuracy: 0.8599
# Epoch 49/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1472 - accuracy: 0.9384 - val_loss: 0.3777 - val_accuracy: 0.8764
# Epoch 50/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1325 - accuracy: 0.9467 - val_loss: 0.3494 - val_accuracy: 0.8779

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_9.history['loss'])
plt.plot(history_9.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that there is a lot of noise in the model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat9 = model9.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat9 = yhat9[:, 0]
# calculate roc curves
fpr, tpr, thresholds9 = roc_curve(y_test, yhat9)
# calculate the g-mean for each threshold
gmeans9 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans9)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds9[ix], gmeans9[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.145695, G-Mean=0.708

# %%
y_pred_e9=model9.predict(X_test_normalized_df)
y_pred_e9 = (y_pred_e9 > thresholds9[ix])
y_pred_e9
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm9=confusion_matrix(y_test, y_pred_e9)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm9, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr6=metrics.classification_report(y_test,y_pred_e9)
print(cr6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.79      0.84      1593
#            1       0.43      0.63      0.52       407
#
#     accuracy                           0.76      2000
#    macro avg       0.66      0.71      0.68      2000
# weighted avg       0.80      0.76      0.77      2000

# %% [markdown]
# Overall the results are no better than the Keras Tuner alone model. From the loss curves of train and validation, the model seems to have overfit.
#
# Let's use Grid Search CV and see if we can increase the model's performance on the metrics.

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v7(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v7, verbose=1)

# %%
# define the grid search parameters
param_grid = {
    'batch_size':[32, 64, 128],
    "lr":[0.001,0.01,0.1],}

kfold_splits = 3
grid = GridSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)
grid_result = grid.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 200/200 [==============================] - 2s 6ms/step - loss: 0.4892 - accuracy: 0.7927 - val_loss: 0.4582 - val_accuracy: 0.8000

# %%
# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
# Out:
# Best: 0.796250 using {'batch_size': 32, 'lr': 0.001}

# %%
estimator_v7=create_model_v7(batch_size=grid_result.best_params_['batch_size'],lr=grid_result.best_params_['lr'])

estimator_v7.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2816
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(grid_result.best_params_['lr'])
estimator_v7.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_7=estimator_v7.fit(X_sm, y_sm, epochs=50, batch_size = grid_result.best_params_['batch_size'], verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 319/319 [==============================] - 3s 6ms/step - loss: 0.5970 - accuracy: 0.6835 - val_loss: 0.6644 - val_accuracy: 0.5871
# Epoch 2/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.5270 - accuracy: 0.7302 - val_loss: 0.8854 - val_accuracy: 0.3991
# Epoch 3/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4859 - accuracy: 0.7597 - val_loss: 0.6715 - val_accuracy: 0.5338
# Epoch 4/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4698 - accuracy: 0.7687 - val_loss: 0.8052 - val_accuracy: 0.4486
# Epoch 5/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4586 - accuracy: 0.7741 - val_loss: 0.6670 - val_accuracy: 0.5965
# Epoch 6/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4600 - accuracy: 0.7783 - val_loss: 0.5731 - val_accuracy: 0.7005
# Epoch 7/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4515 - accuracy: 0.7832 - val_loss: 0.6810 - val_accuracy: 0.5805
# Epoch 8/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4392 - accuracy: 0.7927 - val_loss: 0.5979 - val_accuracy: 0.7308
# Epoch 9/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4372 - accuracy: 0.7993 - val_loss: 0.5787 - val_accuracy: 0.7111
# Epoch 10/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4318 - accuracy: 0.7961 - val_loss: 0.5783 - val_accuracy: 0.7292
# Epoch 11/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4306 - accuracy: 0.7983 - val_loss: 0.4599 - val_accuracy: 0.7696
# Epoch 12/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4248 - accuracy: 0.8045 - val_loss: 0.7648 - val_accuracy: 0.6248
# Epoch 13/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4239 - accuracy: 0.8059 - val_loss: 0.5380 - val_accuracy: 0.7351
# Epoch 14/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4228 - accuracy: 0.8039 - val_loss: 0.6274 - val_accuracy: 0.6652
# Epoch 15/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4197 - accuracy: 0.8063 - val_loss: 0.7038 - val_accuracy: 0.6664
# Epoch 16/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4165 - accuracy: 0.8039 - val_loss: 0.5842 - val_accuracy: 0.7214
# Epoch 17/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4160 - accuracy: 0.8064 - val_loss: 0.5380 - val_accuracy: 0.7265
# Epoch 18/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4074 - accuracy: 0.8122 - val_loss: 0.5486 - val_accuracy: 0.7245
# Epoch 19/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4113 - accuracy: 0.8091 - val_loss: 0.5071 - val_accuracy: 0.7586
# Epoch 20/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4062 - accuracy: 0.8128 - val_loss: 0.4910 - val_accuracy: 0.7582
# Epoch 21/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4047 - accuracy: 0.8105 - val_loss: 0.5551 - val_accuracy: 0.7406
# Epoch 22/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4020 - accuracy: 0.8147 - val_loss: 0.5829 - val_accuracy: 0.7025
# Epoch 23/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4046 - accuracy: 0.8134 - val_loss: 0.5483 - val_accuracy: 0.7374
# Epoch 24/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4012 - accuracy: 0.8126 - val_loss: 0.5087 - val_accuracy: 0.7567
# Epoch 25/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3944 - accuracy: 0.8151 - val_loss: 0.4353 - val_accuracy: 0.7822
# Epoch 26/50
# 319/319 [==============================] - 2s 7ms/step - loss: 0.3980 - accuracy: 0.8145 - val_loss: 0.4915 - val_accuracy: 0.7547
# Epoch 27/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3963 - accuracy: 0.8164 - val_loss: 0.5467 - val_accuracy: 0.7253
# Epoch 28/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3916 - accuracy: 0.8215 - val_loss: 0.5100 - val_accuracy: 0.7398
# Epoch 29/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3910 - accuracy: 0.8176 - val_loss: 0.4821 - val_accuracy: 0.7649
# Epoch 30/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3899 - accuracy: 0.8207 - val_loss: 0.4648 - val_accuracy: 0.7830
# Epoch 31/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3812 - accuracy: 0.8243 - val_loss: 0.5043 - val_accuracy: 0.7555
# Epoch 32/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3840 - accuracy: 0.8220 - val_loss: 0.4482 - val_accuracy: 0.7892
# Epoch 33/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.3845 - accuracy: 0.8227 - val_loss: 0.5041 - val_accuracy: 0.7582
# Epoch 34/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3844 - accuracy: 0.8212 - val_loss: 0.4812 - val_accuracy: 0.7649
# Epoch 35/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3770 - accuracy: 0.8254 - val_loss: 0.4852 - val_accuracy: 0.7398
# Epoch 36/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.3833 - accuracy: 0.8203 - val_loss: 0.4768 - val_accuracy: 0.7641
# Epoch 37/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.3760 - accuracy: 0.8280 - val_loss: 0.5078 - val_accuracy: 0.7323
# Epoch 38/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3788 - accuracy: 0.8249 - val_loss: 0.4487 - val_accuracy: 0.7826
# Epoch 39/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3723 - accuracy: 0.8266 - val_loss: 0.4381 - val_accuracy: 0.8061
# Epoch 40/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3681 - accuracy: 0.8296 - val_loss: 0.4925 - val_accuracy: 0.7626
# Epoch 41/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3751 - accuracy: 0.8278 - val_loss: 0.4620 - val_accuracy: 0.7838
# Epoch 42/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3712 - accuracy: 0.8269 - val_loss: 0.4790 - val_accuracy: 0.7665
# Epoch 43/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3699 - accuracy: 0.8266 - val_loss: 0.4824 - val_accuracy: 0.7771
# Epoch 44/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3720 - accuracy: 0.8258 - val_loss: 0.4289 - val_accuracy: 0.8089
# Epoch 45/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3678 - accuracy: 0.8292 - val_loss: 0.3802 - val_accuracy: 0.8399
# Epoch 46/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.3612 - accuracy: 0.8372 - val_loss: 0.4688 - val_accuracy: 0.7845
# Epoch 47/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3619 - accuracy: 0.8320 - val_loss: 0.3894 - val_accuracy: 0.8151
# Epoch 48/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3632 - accuracy: 0.8288 - val_loss: 0.5494 - val_accuracy: 0.7135
# Epoch 49/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3614 - accuracy: 0.8324 - val_loss: 0.4264 - val_accuracy: 0.7932
# Epoch 50/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.3593 - accuracy: 0.8322 - val_loss: 0.3968 - val_accuracy: 0.8348

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_7.history['loss'])
plt.plot(history_7.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that there is a lot of noise in the model.
#
# Grid Search CV also does not seem to work that well on the SMOTE data.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat10 = estimator_v7.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat10 = yhat10[:, 0]
# calculate roc curves
fpr, tpr, thresholds10 = roc_curve(y_test, yhat10)
# calculate the g-mean for each threshold
gmeans10 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans10)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds10[ix], gmeans10[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.393835, G-Mean=0.753

# %%
y_pred_e10=estimator_v7.predict(X_test_normalized_df)
y_pred_e10 = (y_pred_e10 > thresholds10[ix])
y_pred_e10
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm10=confusion_matrix(y_test, y_pred_e10)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm10, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr10=metrics.classification_report(y_test,y_pred_e10)
print(cr10)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84      1593
#            1       0.45      0.73      0.56       407
#
#     accuracy                           0.76      2000
#    macro avg       0.69      0.75      0.70      2000
# weighted avg       0.82      0.76      0.78      2000

# %% [markdown]
# Oversampling using SMOTE did not help improve the recall score.
#
# In this dataset, the SMOTE oversampling technique does not work well, as both the models we tried building have overfitted on the training dataset.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Our final model here can be Model 4, which uses the Dropout regularization technique and has a good recall score of 76% with also reasonable F1 and accuracy scores. As we saw, it works well on the imbalanced dataset.

# %% [markdown]
# ### Suggested Areas of Improvement

# %% [markdown]
# Build any one Machine Learning model, and use that to get the feature importance of the variables. Try to use that in the neural network model.
#
# We can also do better feature engineerning by removing the flaws of the skewed variables if required.

# %% [markdown]
# ### Business Recommendations

# %% [markdown]
# - The Bank management can deploy the final model from this exercise to identify with a reasonable degree of accuracy whether an customer is likely to churn or not, and this process seems to be easier and more time-efficient than other methods.
# - From EDA, we noticed that the customers from Germany are more likey to churn compared to France and Spain. So the Bank management can take some important measures according to the geography.
# - Similary we noticed that the customers with higher Age like 45 or above are more likely to churn so measures can be taken to incentivize such customers.
