# %% [markdown]
# ## Bank Churn Prediction

# %% [markdown]
# #### Background and Context

# %% [markdown]
# Businesses like banks that provide service have to worry about the problem of 'Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on the improvement of service, keeping in mind these priorities.

# %% [markdown]
# #### Objective

# %% [markdown]
# Given a Bank customer, build a neural network-based classifier that can determine whether they will leave or not in the next 6 months.

# %% [markdown]
# #### Data Dictionary

# %% [markdown]
# - CustomerId: Unique ID which is assigned to each customer
# - Surname: Last name of the customer
# - CreditScore: It defines the credit history of the customer.
# - Geography: A customer’s location
# - Gender: It defines the Gender of the customer
# - Age: Age of the customer
# - Tenure: Number of years for which the customer has been with the bank
# - NumOfProducts: It refers to the number of products that a customer has purchased through the bank.
# - Balance: Account balance
# - HasCrCard: It is a categorical variable that decides whether the customer has a credit card or not.
# - EstimatedSalary: Estimated salary
# - isActiveMember: It is a categorical variable that decides whether the customer is an active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions, etc )
# - Excited: It is a categorical variable that decides whether the customer left the bank within six months or not. It can take two values
#                     0=No ( Customer did not leave the bank )
#
#                     1=Yes ( Customer left the bank )

# %% [markdown]
# ##### Import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# library to import to standardize the data
from sklearn.preprocessing import MinMaxScaler
from sklearn import model_selection
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import warnings
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import random
from tensorflow.keras import backend
random.seed(1)
np.random.seed(1) 
tf.random.set_seed(1)
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Churn.csv')

# %%
data = df.copy()

# %%
# Checking the number of rows and columns in the data
data.shape
# Out:
# (10000, 14)

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Let's check for duplicate values in the data
data.duplicated().sum()
# Out:
# 0

# %%
# Let's check for missing values in the data
round(data.isnull().sum() / data.isnull().count() * 100, 2)
# Out:
# RowNumber          0.0
# CustomerId         0.0
# Surname            0.0
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %%
data["Exited"].value_counts(1)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %%
# Let's view the statistical summary of the numerical columns in the data
data.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# CreditScore           584.00  6.520000e+02  7.180000e+02       850.00
# Age                    32.00  3.700000e+01  4.400000e+01        92.00
# Tenure                  3.00  5.000000e+00  7.000000e+00        10.00
# Balance                 0.00  9.719854e+04  1.276442e+05    250898.09
# NumOfProducts           1.00  1.000000e+00  2.000000e+00         4.00
# HasCrCard               0.00  1.000000e+00  1.000000e+00         1.00
# IsActiveMember          0.00  1.000000e+00  1.000000e+00         1.00
# EstimatedSalary     51002.11  1.001939e+05  1.493882e+05    199992.48
# Exited                  0.00  0.000000e+00  0.000000e+00         1.00

# %%
# Let's check the number of unique values in each column
data.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
for i in data.describe(include=["object"]).columns:
    print("Unique values in", i, "are :")
    print(data[i].value_counts())
    print("*" * 50)
# Out:
# Unique values in Surname are :
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: Surname, Length: 2932, dtype: int64
# **************************************************
# Unique values in Geography are :
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# **************************************************
# Unique values in Gender are :
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# **************************************************

# %% [markdown]
# ##### Dropping the unique columns

# %%
# ID column consists of uniques ID for clients and hence will not add value to the modeling
data.drop(columns="RowNumber", inplace=True)
data.drop(columns="CustomerId", inplace=True)
data.drop(columns="Surname", inplace=True)

# %% [markdown]
# - RowNumber, CustomerId and Surname are unique to each customer and hence will not add vlue to the modeling/analysis

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Univariate Analysis

# %%
# Function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
data.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
histogram_boxplot(data, 'CreditScore')

# %% [markdown]
# - The data is normally distributed with mean around 6.5k.

# %%
histogram_boxplot(data, 'Age')

# %% [markdown]
# - The data is slightly right skewed with mean greater median. The median age is 37 years with some outliers.

# %%
histogram_boxplot(data, 'Tenure')

# %% [markdown]
# - The tenure is range between 0 - 10 years. The mean and median is 5 years.

# %%
histogram_boxplot(data, 'NumOfProducts')

# %%
histogram_boxplot(data, 'EstimatedSalary')

# %% [markdown]
# - The max estimated salary is 200k and the mean and median are around 100k.

# %%
# Function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
labeled_barplot(data, 'Geography', perc=True)

# %% [markdown]
# - 50% of the customers are from France.
# - The other 50% of the customers are equally from Germany and Spain.

# %%
labeled_barplot(data, 'Gender', perc=True)

# %% [markdown]
# - 55% of the customers are male and the remaining are Female.

# %% [markdown]
# ### Bivariate Analysis

# %%
corr_cols = []
for col in data.columns:
    if data[col].dtypes != 'object':
        corr_cols.append(col)
        
plt.figure(figsize=(15, 7))
sns.heatmap(
    data[corr_cols].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %% [markdown]
# - The numerical columns of the data seem to be independent of each other overall.
# - The age column shows slight +ve correlation if the customer is going to churn or not. Similarly how active a member is also -vely correlated with if he/she is going to churn or not.

# %%
### Function to plot distributions


def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of Exited for Exited=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
    )

    axs[0, 1].set_title("Distribution of Exited for Exited=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
    )

    axs[1, 0].set_title("Boxplot w.r.t Exited")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t Exited")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %%
distribution_plot_wrt_target(data, "CreditScore", "Exited")

# %% [markdown]
# We observe that the distribution of the credit score with respect to the target variable is slightly left skewed, and from the box plot for both classes the median credit score are around 650.

# %%
distribution_plot_wrt_target(data, "Age", "Exited")

# %% [markdown]
# We observe that the distribution of the Age with respect to the target variable is rightly skewed, and from the box plot for both class 0 the median Age is around 35 and for class 1 the median Age is 45.

# %%
distribution_plot_wrt_target(data, "Tenure", "Exited")

# %% [markdown]
# We observe that the distribution of the Tenure with respect to the target variable is evenely distributed, and from the box plot for both classes the median Tenure is 5 years.

# %%
distribution_plot_wrt_target(data, "EstimatedSalary", "Exited")

# %% [markdown]
# We observe that the distribution of the Estimated Salary with respect to the target variable is evenly distributed, and from the box plot for both classes the median estimated salary is around 100k.

# %%
# function to plot stacked bar chart


def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left",
        frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
stacked_barplot(data, "Geography", "Exited")
# Out:
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Almost twice the number of customers from Germany churned compared to Spain and France.

# %%
stacked_barplot(data, "Gender", "Exited")
# Out:
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - More female customers churned compared to male customers.

# %% [markdown]
# ### If the data is imbalanced ?

# %%
print(data.Exited.value_counts())
labels = 'Customer left the bank', 'Customer did not leave the bank'
#sizes = [ds.is_promoted[ds['is_promoted']==1].count(), ds.is_promoted[ds['is_promoted']==0].count()]
sizes = [data.Exited[data['Exited']==1].count(),data.Exited[data['Exited']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Proportion", size = 20)
plt.show()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# ### Data Pre-processing

# %%
## Separating Independent and Dependent Columns
X = data.drop(['Exited'],axis=1)
Y = data[['Exited']]

# %%
Y.head()
# Out:
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
# Splitting the dataset into the Training and Testing set.

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42,stratify = Y)

# %%
X_train.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64

# %%
# Checking that no column has missing values in train and test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64
# ------------------------------
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64

# %% [markdown]
# #### Encoding Categorical Columns

# %%
labelencoder_G = LabelEncoder()
X_train['Geography']=  labelencoder_G.fit_transform(X_train['Geography'])
X_test['Geography']=  labelencoder_G.transform(X_test['Geography'])

# %%
labelencoder_A = LabelEncoder()
X_train['Gender']=  labelencoder_A.fit_transform(X_train['Gender'])
X_test['Gender']=  labelencoder_A.transform(X_test['Gender'])

# %%
X_train.head()
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 2151          753          0       1   39       7       0.00              1
# 8392          739          1       1   14       3  102128.27              1
# 5006          755          1       0   19       0  113865.23              2
# 4117          561          0       1   19       5       0.00              2
# 7182          692          1       1   31       6  110540.43              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 2151          1               0        159475.08
# 8392          1               0         63981.37
# 5006          1               1        117396.25
# 4117          1               0         83093.25
# 7182          0               1        107472.99

# %%
data["Geography"].value_counts(1)
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %%
y_train.head()
# Out:
#       Exited
# 2151       1
# 8392       1
# 5006       0
# 4117       0
# 7182       0

# %%
###Checking the shape of train and test sets
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000, 10)
# (2000, 10)
# (8000, 1)
# (2000, 1)

# %% [markdown]
# #### Scaling

# %%
scaler = MinMaxScaler()

# Here, we are passing all the features (numerical and categorical), that's okay as min-max scaler will not change values of categorical variables
X_train_normalized = scaler.fit_transform(X_train)

# %%
X_test_normalized = scaler.transform(X_test)

# %%
np.set_printoptions(suppress=True)
print(X_train_normalized)
# Out:
# [[0.806      0.         1.         ... 1.         0.         0.79739365]
#  [0.778      0.5        1.         ... 1.         0.         0.3198795 ]
#  [0.81       0.5        0.         ... 1.         1.         0.58697941]
#  ...
#  [0.634      0.         0.         ... 1.         1.         0.33864839]
#  [0.674      1.         1.         ... 1.         0.         0.11118907]
#  [0.904      1.         1.         ... 0.         1.         0.20424055]]

# %%
X_train_normalized_df = pd.DataFrame(X_train_normalized, index=X_train.index, columns=X_train.columns)
X_test_normalized_df = pd.DataFrame(X_test_normalized, index=X_test.index, columns=X_test.columns)

# %%
X_train_normalized_df.head()
# Out:
#       CreditScore  Geography  Gender       Age  Tenure   Balance  \
# 2151        0.806        0.0     1.0  0.573529     0.7  0.000000
# 8392        0.778        0.5     1.0  0.205882     0.3  0.428413
# 5006        0.810        0.5     0.0  0.279412     0.0  0.477648
# 4117        0.422        0.0     1.0  0.279412     0.5  0.000000
# 7182        0.684        0.5     1.0  0.455882     0.6  0.463700
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 2151       0.000000        1.0             0.0         0.797394
# 8392       0.000000        1.0             0.0         0.319879
# 5006       0.333333        1.0             1.0         0.586979
# 4117       0.333333        1.0             0.0         0.415448
# 7182       0.333333        0.0             1.0         0.537358

# %%
X_test_normalized_df.head()
# Out:
#       CreditScore  Geography  Gender       Age  Tenure   Balance  \
# 5702        0.470        0.0     1.0  0.529412     0.7  0.000000
# 3667        0.350        0.5     1.0  0.485294     0.4  0.549625
# 1617        0.414        1.0     0.0  0.588235     0.4  0.000000
# 5673        0.578        1.0     1.0  0.500000     0.5  0.584733
# 4272        0.580        1.0     0.0  0.500000     0.3  0.326472
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 5702       0.333333        1.0             0.0         0.471403
# 3667       0.333333        0.0             0.0         0.275333
# 1617       0.333333        0.0             1.0         0.527160
# 5673       0.333333        0.0             0.0         0.169709
# 4272       0.000000        1.0             1.0         0.842747

# %%
X_train.head()
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 2151          753          0       1   39       7       0.00              1
# 8392          739          1       1   14       3  102128.27              1
# 5006          755          1       0   19       0  113865.23              2
# 4117          561          0       1   19       5       0.00              2
# 7182          692          1       1   31       6  110540.43              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 2151          1               0        159475.08
# 8392          1               0         63981.37
# 5006          1               1        117396.25
# 4117          1               0         83093.25
# 7182          0               1        107472.99

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model evaluation criterion:

# %% [markdown]
# #### A model can make wrong predictions in the following ways:

# %% [markdown]
# 1. Predicting a customer is going to churn but in reality, the customer is not going to churn - Loss of resources
# 2. Predicting a customer is not going to churn but in reality the customer is going to churn - Loss of opportunity

# %% [markdown]
# #### Which case is more important?

# %% [markdown]
# - Predicting a customer is not going to churn but in reality the customer is going to churn i.e. losing on a potential opportunity as the customer will not be targeted by the Bank when he should be targeted.

# %% [markdown]
# #### How to reduce this loss i.e need to reduce False Negatives?

# %% [markdown]
# - Bank would want Recall to be maximized, greater the Recall lesser the chances of false negatives.

# %% [markdown]
# ### Model 1

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the ANN
model1 = Sequential()
# The amount of nodes (dimensions) in hidden layer should be the average of input and output layers, in this case 64.
# This adds the input layer (by specifying input dimension) AND the first hidden layer (units)
model1.add(Dense(activation = 'relu', input_dim = X_train.shape[1], units=64))
#Add 1st hidden layer
model1.add(Dense(32, activation='relu'))
# Adding the output layer
# Notice that we do not need to specify input dim. 
# we have an output of 1 node, which is the the desired dimensions of our output (stay with the bank or not)
# We use the sigmoid because we want probability outcomes
model1.add(Dense(1, activation = 'sigmoid'))

# %%
# Create optimizer with default learning rate
# Compile the model
model1.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                704
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,817
# Trainable params: 2,817
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model1.fit(X_train_normalized_df, y_train,           
          validation_split=0.2,
          epochs=50,
          batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 2s 4ms/step - loss: 0.5218 - accuracy: 0.7917 - val_loss: 0.4898 - val_accuracy: 0.8000
# Epoch 2/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4926 - accuracy: 0.7953 - val_loss: 0.4840 - val_accuracy: 0.8000
# Epoch 3/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7953 - val_loss: 0.4789 - val_accuracy: 0.8000
# Epoch 4/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.7953 - val_loss: 0.4743 - val_accuracy: 0.8000
# Epoch 5/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4756 - accuracy: 0.7953 - val_loss: 0.4706 - val_accuracy: 0.8000
# Epoch 6/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4711 - accuracy: 0.7953 - val_loss: 0.4673 - val_accuracy: 0.8000
# Epoch 7/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4673 - accuracy: 0.7953 - val_loss: 0.4646 - val_accuracy: 0.8000
# Epoch 8/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4638 - accuracy: 0.7953 - val_loss: 0.4617 - val_accuracy: 0.8000
# Epoch 9/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4605 - accuracy: 0
# Epoch 46/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8202 - val_loss: 0.4254 - val_accuracy: 0.8206
# Epoch 47/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8203 - val_loss: 0.4258 - val_accuracy: 0.8175
# Epoch 48/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4160 - accuracy: 0.8203 - val_loss: 0.4235 - val_accuracy: 0.8231
# Epoch 49/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.8198 - val_loss: 0.4226 - val_accuracy: 0.8263
# Epoch 50/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8222 - val_loss: 0.4215 - val_accuracy: 0.8238

# %%
# Capturing learning history per epoch
hist  = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# Plotting accuracy at different epochs
plt.plot(hist['loss'])
plt.plot(hist['val_loss'])
plt.legend(("train" , "valid") , loc =0)

#Printing results
results = model1.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 15960.7285 - accuracy: 0.2050

# %%
y_pred=model1.predict(X_test_normalized_df)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 63/63 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))



    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    
    if title:
        plt.title(title)

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %% [markdown]
# Here, the 21.8% of False Negatives is because we gave 0.5 as the threshold to the model, and as this is an imbalanced dataset, we should calculate the threshold using the AUC-ROC curve.

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.80      1593
#            1       0.39      0.69      0.50       407
#
#     accuracy                           0.72      2000
#    macro avg       0.65      0.71      0.65      2000
# weighted avg       0.80      0.72      0.74      2000

# %% [markdown]
# As we can see, the above model has a relatively poor recall score. This could be due to the imbalanced dataset. We observe that the False negative rates are also high, which should be considerably lower.
#
# 1) Imbalanced dataset: As you have seen in the EDA, this dataset is imbalanced, and it contains more examples that belong to the 0 class.
#
# 2) Decision Threshold: Due to the imbalanced dataset, we can use ROC-AUC to find the optimal threshold and use the same for prediction.
#
# Let's try to change the optimizer, tune the decision threshold, increase the layers and configure some other hyperparameters accordingly, in order to improve the model's performance.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat1 = model1.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat1 = yhat1[:, 0]
# calculate roc curves
fpr, tpr, thresholds1 = roc_curve(y_test, yhat1)
# calculate the g-mean for each threshold
gmeans1 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans1)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds1[ix], gmeans1[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.693326, G-Mean=0.649

# %%
#Predicting the results using best as a threshold
y_pred_e1=model1.predict(X_test_normalized_df)
y_pred_e1 = (y_pred_e1 > thresholds1[ix])
y_pred_e1
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred_e1)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred_e1)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.75      0.81      1593
#            1       0.36      0.56      0.44       407
#
#     accuracy                           0.71      2000
#    macro avg       0.62      0.65      0.62      2000
# weighted avg       0.77      0.71      0.73      2000

# %% [markdown]
# - Using the ROC-AUC threshold, we can see the False negatives have reduced however, there is a slight decrease in macro recall score.

# %% [markdown]
# ### Model 2

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model1 = Sequential()
      #Adding the hidden and output layers
model1.add(Dense(256,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model1.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(1, activation = 'sigmoid'))
      #Compiling the ANN with Adam optimizer and binary cross entropy loss function 
optimizer = tf.keras.optimizers.Adam(0.001)
model1.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2816
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model1.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 7ms/step - loss: 0.4689 - accuracy: 0.7967 - val_loss: 0.4492 - val_accuracy: 0.8094
# Epoch 2/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4253 - accuracy: 0.8234 - val_loss: 0.4072 - val_accuracy: 0.8338
# Epoch 3/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3962 - accuracy: 0.8314 - val_loss: 0.3872 - val_accuracy: 0.8456
# Epoch 4/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3697 - accuracy: 0.8469 - val_loss: 0.3614 - val_accuracy: 0.8587
# Epoch 5/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3615 - accuracy: 0.8509 - val_loss: 0.3518 - val_accuracy: 0.8581
# Epoch 6/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3589 - accuracy: 0.8514 - val_loss: 0.3463 - val_accuracy: 0.8575
# Epoch 7/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3482 - accuracy: 0.8537 - val_loss: 0.3498 - val_accuracy: 0.8587
# Epoch 8/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3438 - accuracy: 0.8620 - val_loss: 0.3429 - val_accuracy: 0.8619
# Epoch 9/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3370 - accuracy: 0.8620 - val_loss: 0.3441 - val_accuracy: 0.8612
# Epoch 10/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3339 - accuracy: 0.8636 - val_loss: 0.3427 - val_accuracy: 0.8637
# Epoch 11/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3291 - accuracy: 0.8605 - val_loss: 0.3568 - val_accuracy: 0.8587
# Epoch 12/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3293 - accuracy: 0.8628 - val_loss: 0.3441 - val_accuracy: 0.8662
# Epoch 13/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3268 - accuracy: 0.8634 - val_loss: 0.3536 - val_accuracy: 0.8625
# Epoch 14/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3233 - accuracy: 0.8647 - val_loss: 0.3444 - val_accuracy: 0.8650
# Epoch 15/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.
50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.9089 - val_loss: 0.4547 - val_accuracy: 0.8562
# Epoch 48/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2163 - accuracy: 0.9092 - val_loss: 0.4694 - val_accuracy: 0.8444
# Epoch 49/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.9109 - val_loss: 0.4706 - val_accuracy: 0.8537
# Epoch 50/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9150 - val_loss: 0.4731 - val_accuracy: 0.8356

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - As we increased the number of layers, we see from the diverging train and validation curves that the model is over-fitted.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat1 = model1.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat1 = yhat1[:, 0]
# calculate roc curves
fpr, tpr, thresholds1 = roc_curve(y_test, yhat1)
# calculate the g-mean for each threshold
gmeans1 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans1)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds1[ix], gmeans1[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.693326, G-Mean=0.649

# %%
#Predicting the results using best as a threshold
y_pred_e1=model1.predict(X_test_normalized_df)
y_pred_e1 = (y_pred_e1 > thresholds1[ix])
y_pred_e1
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(y_test, y_pred_e1)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm1, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred_e1)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.75      0.81      1593
#            1       0.36      0.56      0.44       407
#
#     accuracy                           0.71      2000
#    macro avg       0.62      0.65      0.62      2000
# weighted avg       0.77      0.71      0.73      2000

# %% [markdown]
# As the number of layers in the neural network has increased, we can see that the macro recall score has decreased slightly but the False Negative percentage has improved (i.e. percentage reduced.)
#
# Now let's try to use the Batch Normalization technique and check to see if we can increase the recall score.

# %% [markdown]
# ### Model 3

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model3 = Sequential()
model3.add(Dense(128,activation='relu',input_dim = X_train.shape[1]))
model3.add(BatchNormalization())
model3.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model3.add(BatchNormalization())
model3.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
model3.add(Dense(1, activation = 'sigmoid'))

# %%
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 12,545
# Trainable params: 12,161
# Non-trainable params: 384
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_3 = model2.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2002 - accuracy: 0.9159 - val_loss: 0.4927 - val_accuracy: 0.8413
# Epoch 2/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1994 - accuracy: 0.9169 - val_loss: 0.4908 - val_accuracy: 0.8419
# Epoch 3/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1949 - accuracy: 0.9183 - val_loss: 0.4885 - val_accuracy: 0.8444
# Epoch 4/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1899 - accuracy: 0.9189 - val_loss: 0.5376 - val_accuracy: 0.8325
# Epoch 5/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1889 - accuracy: 0.9191 - val_loss: 0.5242 - val_accuracy: 0.8400
# Epoch 6/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9214 - val_loss: 0.5274 - val_accuracy: 0.8438
# Epoch 7/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1748 - accuracy: 0.9284 - val_loss: 0.5401 - val_accuracy: 0.8381
# Epoch 8/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1707 - accuracy: 0.9291 - val_loss: 0.5762 - val_accuracy: 0.8406
# Epoch 9/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1771 - accuracy: 0.9266 - val_loss: 0.5515 - val_accuracy: 0.8350
# Epoch 10/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.9294 - val_loss: 0.5663 - val_accuracy: 0.8375
# Epoch 11/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1738 - accuracy: 0.9278 - val_loss: 0.5573 - val_accuracy: 0.8338
# Epoch 12/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1635 - accuracy: 0.9303 - val_loss: 0.5758 - val_accuracy: 0.8319
# Epoch 13/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1609 - accuracy: 0.9300 - val_loss: 0.5894 - val_accuracy: 0.8194
# Epoch 14/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1559 - accuracy: 0.9333 - val_loss: 0.6006 - val_accuracy: 0.8350
# Epoch 15/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1545 - accuracy: 0.9356 - val_loss: 0.6193 - val_accuracy: 0.8238
# Epoch 16/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1526 - accuracy: 0.9348 - val_loss: 0.6250 - val_accuracy: 0.8131
# Epoch 17/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1534 - accuracy: 0.9398 - val_loss: 0.6400 - val_accuracy: 0.8094
# Epoch 18/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1443 - accuracy: 0.9406 - val_loss: 0.6153 - val_accuracy: 0.8281
# Epoch 19/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1405 - accuracy: 0.9428 - val_loss: 0.6496 - val_accuracy: 0.8462
# Epoch 20/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1388 - accuracy: 0.9436 - val_loss: 0.6609 - val_accuracy: 0.8263
# Epoch 21/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1387 - accuracy: 0.9441 - val_loss: 0.6486 - val_accuracy: 0.8306
# Epoch 22/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1329 - accuracy: 0.9452 - val_loss: 0.6758 - val_accuracy: 0.8419
# Epoch 23/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1321 - accuracy: 0.9438 - val_loss: 0.6813 - val_accuracy: 0.8231
# Epoch 24/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1286 - accuracy: 0.9488 - val_loss: 0.7007 - val_accuracy: 0.8281
# Epoch 25/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.9517 - val_loss: 0.7208 - val_accuracy: 0.8200
# Epoch 26/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1212 - accuracy: 0.9519 - val_loss: 0.7191 - val_accuracy: 0.8325
# Epoch 27/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1261 - accuracy: 0.9492 - val_loss: 0.7487 - val_accuracy: 0.8181
# Epoch 28/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1185 - accuracy: 0.9484 - val_loss: 0.7438 - val_accuracy: 0.8338
# Epoch 29/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.9475 - val_loss: 0.7637 - val_accuracy: 0.8363
# Epoch 30/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1117 - accuracy: 0.9538 - val_loss: 0.7556 - val_accuracy: 0.8325
# Epoch 31/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1058 - accuracy: 0.9553 - val_loss: 0.8110 - val_accuracy: 0.8281
# Epoch 32/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1052 - accuracy: 0.9569 - val_loss: 0.7775 - val_accuracy: 0.8369
# Epoch 33/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9538 - val_loss: 0.8406 - val_accuracy: 0.8319
# Epoch 34/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9541 - val_loss: 0.8279 - val_accuracy: 0.8231
# Epoch 35/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1060 - accuracy: 0.9558 - val_loss: 0.8472 - val_accuracy: 0.8356
# Epoch 36/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0983 - accuracy: 0.9581 - val_loss: 0.8515 - val_accuracy: 0.8319
# Epoch 37/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1067 - accuracy: 0.9544 - val_loss: 0.8611 - val_accuracy: 0.8194
# Epoch 38/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0974 - accuracy: 0.9631 - val_loss: 0.8385 - val_accuracy: 0.8325
# Epoch 39/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1024 - accuracy: 0.9572 - val_loss: 0.8520 - val_accuracy: 0.8225
# Epoch 40/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0897 - accuracy: 0.9645 - val_loss: 0.9127 - val_accuracy: 0.8006
# Epoch 41/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1033 - accuracy: 0.9569 - val_loss: 0.8765 - val_accuracy: 0.8363
# Epoch 42/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9638 - val_loss: 0.9018 - val_accuracy: 0.8313
# Epoch 43/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.9656 - val_loss: 0.9264 - val_accuracy: 0.8244
# Epoch 44/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0915 - accuracy: 0.9628 - val_loss: 0.8961 - val_accuracy: 0.8256
# Epoch 45/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0819 - accuracy: 0.9670 - val_loss: 0.9337 - val_accuracy: 0.8288
# Epoch 46/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0811 - accuracy: 0.9680 - val_loss: 0.9408 - val_accuracy: 0.8156
# Epoch 47/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0778 - accuracy: 0.9691 - val_loss: 0.9654 - val_accuracy: 0.8206
# Epoch 48/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0822 - accuracy: 0.9694 - val_loss: 0.9801 - val_accuracy: 0.8288
# Epoch 49/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9667 - val_loss: 0.9714 - val_accuracy: 0.8169
# Epoch 50/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0814 - accuracy: 0.9695 - val_loss: 0.9934 - val_accuracy: 0.8125

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - Unfortunately, from the above plot we seem to have overfitted on the training data because there is a significant difference in performance between train and validation.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat3 = model3.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat3 = yhat3[:, 0]
# calculate roc curves
fpr, tpr, thresholds3 = roc_curve(y_test, yhat3)
# calculate the g-mean for each threshold
gmeans3 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans3)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds3[ix], gmeans3[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.500973, G-Mean=0.622

# %%
y_pred_e3=model3.predict(X_test_normalized_df)
y_pred_e3 = (y_pred_e3 > thresholds3[ix])
y_pred_e3
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm3=confusion_matrix(y_test, y_pred_e3)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm3, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr3=metrics.classification_report(y_test,y_pred_e3)
print(cr3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75      1593
#            1       0.31      0.58      0.40       407
#
#     accuracy                           0.65      2000
#    macro avg       0.58      0.62      0.58      2000
# weighted avg       0.75      0.65      0.68      2000

# %% [markdown]
# The model shows a poor recall scrore and a high False Negative rate.
#
# Let's try to use the Dropout technique and check to see if it can reduce the False Negative rate.

# %% [markdown]
# ### Model 4

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model4 = Sequential()
model4.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
model4.add(Dropout(0.3))
model4.add(Dense(128,activation='relu'))
model4.add(Dropout(0.3))
model4.add(Dense(64,activation='relu'))
model4.add(Dropout(0.3))
model4.add(Dense(32,activation='relu'))
model4.add(Dense(1, activation = 'sigmoid'))

# %%
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2816
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_4 = model4.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s
50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3356 - accuracy: 0.8612 - val_loss: 0.3321 - val_accuracy: 0.8681
# Epoch 35/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3362 - accuracy: 0.8650 - val_loss: 0.3378 - val_accuracy: 0.8656
# Epoch 36/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3297 - accuracy: 0.8625 - val_loss: 0.3409 - val_accuracy: 0.8631
# Epoch 37/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3312 - accuracy: 0.8656 - val_loss: 0.3333 - val_accuracy: 0.8763
# Epoch 38/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3322 - accuracy: 0.8591 - val_loss: 0.3369 - val_accuracy: 0.8637
# Epoch 39/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3327 - accuracy: 0.8603 - val_loss: 0.3348 - val_accuracy: 0.8687
# Epoch 40/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3272 - accuracy: 0.8662 - val_loss: 0.3421 - val_accuracy: 0.8656
# Epoch 41/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3264 - accuracy: 0.8612 - val_loss: 0.3351 - val_accuracy: 0.8687
# Epoch 42/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3314 - accuracy: 0.8636 - val_loss: 0.3350 - val_accuracy: 0.8681
# Epoch 43/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3286 - accuracy: 0.8617 - val_loss: 0.3398 - val_accuracy: 0.8719
# Epoch 44/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3274 - accuracy: 0.8625 - val_loss: 0.3425 - val_accuracy: 0.8631
# Epoch 45/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3243 - accuracy: 0.8678 - val_loss: 0.3456 - val_accuracy: 0.8656
# Epoch 46/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3253 - accuracy: 0.8633 - val_loss: 0.3405 - val_accuracy: 0.8644
# Epoch 47/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3276 - accuracy: 0.8675 - val_loss: 0.3385 - val_accuracy: 0.8650
# Epoch 48/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3223 - accuracy: 0.8644 - val_loss: 0.3400 - val_accuracy: 0.8606
# Epoch 49/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3225 - accuracy: 0.8675 - val_loss: 0.3499 - val_accuracy: 0.8625
# Epoch 50/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3227 - accuracy: 0.8659 - val_loss: 0.3451 - val_accuracy: 0.8600

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that both the curves train and validation are smoother and not over-fitted like in the previous model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat4 = model4.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat4 = yhat4[:, 0]
# calculate roc curves
fpr, tpr, thresholds4 = roc_curve(y_test, yhat4)
# calculate the g-mean for each threshold
gmeans4 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans4)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds4[ix], gmeans4[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.483967, G-Mean=0.692

# %%
y_pred_e4=model4.predict(X_test_normalized_df)
y_pred_e4 = (y_pred_e4 > thresholds4[ix])
y_pred_e4
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm4=confusion_matrix(y_test, y_pred_e4)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm4, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr4=metrics.classification_report(y_test,y_pred_e4)
print(cr4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79      1593
#            1       0.37      0.67      0.48       407
#
#     accuracy                           0.70      2000
#    macro avg       0.63      0.69      0.64      2000
# weighted avg       0.79      0.70      0.73      2000

# %% [markdown]
# The Dropout technique helped the model reduce the loss function of both train and validation. The recall score also seems to be fine, with a decrease in the False Negative rate.
#
# Now, let's try to use some of the Hyperparameter Optimization techniques we have learnt, such as RandomizedSearchCV, GridSearchCV and Keras Tuner to increase the recall score of the model.

# %% [markdown]
# ### Model 5

# %% [markdown]
# #### Random Search CV

# %% [markdown]
# Some important hyperparameters to look out for while optimizing neural networks are:
#
# - Type of Architecture
#
# - Number of Layers
#
# - Number of Neurons in a layer
#
# - Regularization hyperparameters
#
# - Learning Rate
#
# - Type of Optimizer
#
# - Dropout Rate

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v4(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v4, verbose=1)
# define the grid search parameters
param_random = {
    'batch_size':[32, 64, 128],
    "lr":[0.01,0.1,0.001],}

kfold_splits = 3
random= RandomizedSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_distributions=param_random,n_jobs=-1)

# %%
random_result = random.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (random_result.best_score_, random_result.best_params_))
means = random_result.cv_results_['mean_test_score']
stds = random_result.cv_results_['std_test_score']
params = random_result.cv_results_['params']
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 200/200 [==============================] - 2s 5ms/step - loss: 0.4812 - accuracy: 0.7977 - val_loss: 0.4529 - val_accuracy: 0.8075
# Best: 0.796250 using {'lr': 0.01, 'batch_size': 32}

# %%
estimator_v4=create_model_v4(batch_size=random_result.best_params_['batch_size'],lr=random_result.best_params_['lr'])

estimator_v4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2816
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(random_result.best_params_['lr'])
estimator_v4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_4=estimator_v4.fit(X_train_normalized_df, y_train, epochs=50, batch_size = 64, verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s
50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3524 - accuracy: 0.8525 - val_loss: 0.3225 - val_accuracy: 0.8750
# Epoch 36/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3540 - accuracy: 0.8477 - val_loss: 0.3393 - val_accuracy: 0.8625
# Epoch 37/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3513 - accuracy: 0.8572 - val_loss: 0.3248 - val_accuracy: 0.8687
# Epoch 38/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3547 - accuracy: 0.8539 - val_loss: 0.3355 - val_accuracy: 0.8650
# Epoch 39/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3578 - accuracy: 0.8498 - val_loss: 0.3378 - val_accuracy: 0.8675
# Epoch 40/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3500 - accuracy: 0.8559 - val_loss: 0.3397 - val_accuracy: 0.8662
# Epoch 41/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3542 - accuracy: 0.8498 - val_loss: 0.3383 - val_accuracy: 0.8631
# Epoch 42/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3571 - accuracy: 0.8533 - val_loss: 0.3290 - val_accuracy: 0.8662
# Epoch 43/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3551 - accuracy: 0.8523 - val_loss: 0.3426 - val_accuracy: 0.8694
# Epoch 44/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3493 - accuracy: 0.8520 - val_loss: 0.3409 - val_accuracy: 0.8644
# Epoch 45/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3497 - accuracy: 0.8534 - val_loss: 0.3309 - val_accuracy: 0.8694
# Epoch 46/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3481 - accuracy: 0.8548 - val_loss: 0.3408 - val_accuracy: 0.8669
# Epoch 47/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3545 - accuracy: 0.8541 - val_loss: 0.3393 - val_accuracy: 0.8731
# Epoch 48/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3477 - accuracy: 0.8544 - val_loss: 0.3329 - val_accuracy: 0.8744
# Epoch 49/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3494 - accuracy: 0.8564 - val_loss: 0.3384 - val_accuracy: 0.8725
# Epoch 50/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3480 - accuracy: 0.8567 - val_loss: 0.3361 - val_accuracy: 0.8706

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that there is noise in the both training and validation behavior of the model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat4 = estimator_v4.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat4 = yhat4[:, 0]
# calculate roc curves
fpr, tpr, thresholds4 = roc_curve(y_test, yhat4)
# calculate the g-mean for each threshold
gmeans4 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans4)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds4[ix], gmeans4[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.653126, G-Mean=0.706

# %%
y_pred_e4=estimator_v4.predict(X_test_normalized_df)
y_pred_e4 = (y_pred_e4 > thresholds4[ix])
y_pred_e4
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm4=confusion_matrix(y_test, y_pred_e4)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm4, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr4=metrics.classification_report(y_test,y_pred_e4)
print(cr4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      1593
#            1       0.45      0.61      0.52       407
#
#     accuracy                           0.77      2000
#    macro avg       0.67      0.71      0.68      2000
# weighted avg       0.80      0.77      0.78      2000

# %% [markdown]
# Hyperparameter tuning with Grid Search has been used here to get a better recall score, but the recall score might differ each time.
#
# Other hyperparameters can also be tuned to get better metrics.
#
# Here, the recall score of the model, while better than in Randomized Search, is slightly lower than in Model 1 (the simple model).

# %% [markdown]
# ### Model 6

# %% [markdown]
# #### Grid Search CV

# %% [markdown]
# Some important hyperparameters to look out for while optimizing neural networks are:
#
# - Type of Architecture
#
# - Number of Layers
#
# - Number of Neurons in a layer
#
# - Regularization hyperparameters
#
# - Learning Rate
#
# - Type of Optimizer
#
# - Dropout Rate

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v5(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %% [markdown]
# We're using Grid Search to optimize two hyperparameters - Batch Size & Learning Rate.
#
# We can also optimize the other hyperparameters as mentioned above.

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v5, verbose=1)
# define the grid search parameters
param_grid = {
    'batch_size':[64,32, 128],
    "lr":[0.01,0.1,0.001],}

kfold_splits = 3
grid = GridSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)

# %%
import time
  
# store starting time
begin = time.time()


grid_result = grid.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

time.sleep(1)
# store end time
end = time.time()
  
# total time taken
print(f"Total runtime of the program is {end - begin}")
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4786 - accuracy: 0.7942 - val_loss: 0.4789 - val_accuracy: 0.8000
# Best: 0.796250 using {'batch_size': 64, 'lr': 0.01}
# Total runtime of the program is 43.78628444671631

# %% [markdown]
# The best model has the following configuration:
#
# ( It may vary each time the code runs )

# %%
estimator_v5=create_model_v5(batch_size=grid_result.best_params_['batch_size'],lr=grid_result.best_params_['lr'])

estimator_v5.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2816
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(grid_result.best_params_['lr'])
estimator_v5.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_5=estimator_v5.fit(X_train_normalized_df, y_train, epochs=50, batch_size = 64, verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 8ms/step - loss: 0.4769 - accuracy: 0.7947 - val_loss: 0.4735 - val_accuracy: 0.8000
# Epoch 2/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4434 - accuracy: 0.8106 - val_loss: 0.4343 - val_accuracy: 0.8225
# Epoch 3/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4155 - accuracy: 0.8275 - val_loss: 0.3880 - val_accuracy: 0.8269
# Epoch 4/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4021 - accuracy: 0.8352 - val_loss: 0.3795 - val_accuracy: 0.8256
# Epoch 5/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4018 - accuracy: 0.8352 - val_loss: 0.3629 - val_accuracy: 0.8619
# Epoch 6/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.
# Epoch 41/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3688 - accuracy: 0.8483 - val_loss: 0.3404 - val_accuracy: 0.8706
# Epoch 42/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3671 - accuracy: 0.8491 - val_loss: 0.3451 - val_accuracy: 0.8669
# Epoch 43/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3674 - accuracy: 0.8478 - val_loss: 0.3345 - val_accuracy: 0.8669
# Epoch 44/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3636 - accuracy: 0.8505 - val_loss: 0.3371 - val_accuracy: 0.8737
# Epoch 45/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3615 - accuracy: 0.8505 - val_loss: 0.3416 - val_accuracy: 0.8694
# Epoch 46/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3610 - accuracy: 0.8495 - val_loss: 0.3405 - val_accuracy: 0.8687
# Epoch 47/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3677 - accuracy: 0.8498 - val_loss: 0.3421 - val_accuracy: 0.8625
# Epoch 48/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3548 - accuracy: 0.8520 - val_loss: 0.3339 - val_accuracy: 0.8750
# Epoch 49/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3632 - accuracy: 0.8498 - val_loss: 0.3410 - val_accuracy: 0.8694
# Epoch 50/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3603 - accuracy: 0.8508 - val_loss: 0.3433 - val_accuracy: 0.8637

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that both curves - train and validation, are relatively smooth.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat5 = estimator_v5.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat5 = yhat5[:, 0]
# calculate roc curves
fpr, tpr, thresholds5 = roc_curve(y_test, yhat5)
# calculate the g-mean for each threshold
gmeans5 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans5)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds5[ix], gmeans5[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step
# Best Threshold=0.600966, G-Mean=0.717

# %%
y_pred_e5=estimator_v5.predict(X_test_normalized_df)
y_pred_e5 = (y_pred_e5 > thresholds5[ix])
y_pred_e5
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm5=confusion_matrix(y_test, y_pred_e5)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm5, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr6=metrics.classification_report(y_test,y_pred_e5)
print(cr6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87      1593
#            1       0.50      0.61      0.55       407
#
#     accuracy                           0.80      2000
#    macro avg       0.70      0.73      0.71      2000
# weighted avg       0.81      0.80      0.80      2000

# %% [markdown]
# Hyperparameter tuning with Grid Search has been used here to get a better recall score, but the recall score might differ each time.
#
# Other hyperparameters can also be tuned to get better metrics.
#
# Here, the recall score of the model is the best model we have seen so far, better than the Randomized search and the basic Model 1. It has not only better recall score but also good values for F1 score and accuracy.

# %% [markdown]
# ### DASK

# %% [markdown]
# - There is also another library called Dask, sometimes used in the industry to provide a performance boost to Hyperparameter Tuning due to its parallelized computing procedure.
# - Dask also has the option of implementing Grid Search similar to the Grid Search in Scikit-learn.

# %%
# importing library
from dask_ml.model_selection import GridSearchCV as DaskGridSearchCV

# %%
def create_model_v6(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v6, verbose=1)
# define the grid search parameters
param_grid = {
    'batch_size':[64,32, 128],
    "lr":[0.001,0.01,0.1],}

kfold_splits = 3
dask = DaskGridSearchCV(estimator=keras_estimator, 
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)

# %%
import time
  
# store starting time
begin = time.time()


dask_result = dask.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (dask_result.best_score_, dask_result.best_params_))
means = dask_result.cv_results_['mean_test_score']
stds = dask_result.cv_results_['std_test_score']
params = dask_result.cv_results_['params']

time.sleep(1)
# store end time
end = time.time()
  
# total time taken
print(f"Total runtime of the program is {end - begin}")
# Out:
# 67/67 [==============================] - 5s 26ms/step - loss: 0.5201 - accuracy: 0.7829 - val_loss: 0.4722 - val_accuracy: 0.8032
# 67/67 [==============================] - 5s 28ms/step - loss: 0.5109 - accuracy: 0.7912 - val_loss: 0.4842 - val_accuracy: 0.7844
# 67/67 [==============================] - 5s 29ms/step - loss: 0.5243 - accuracy: 0.7717 - val_loss: 0.4666 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s 13ms/step - loss: 0.4841 - accuracy: 0.7885
# 42/42 [==============================] - 1s 13ms/step - loss: 0.4771 - accuracy: 0.7926
# 67/67 [==============================] - 6s 35ms/step - loss: 0.4921 - accuracy: 0.7951 - val_loss: 0.4550 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s 15ms/step - loss: 0.4555 - accuracy: 0.8076
# 42/42 [==============================] - 1s 21ms/step - loss: 0.4612 - accuracy: 0.7885
# 67/67 [==============================] - 6s 34ms/step - loss: 0.5003 - accuracy: 0.7853 - val_loss: 0.4530 - val_accuracy: 0.8032
# 67/67 [==============================] - 6s 34ms/step - loss: 0.4899 - accuracy: 0.7949 - val_loss: 0.4837 - val_accuracy: 0.7844
# 42/42 [==============================] - 1s 15ms/step - loss: 0.4329 - accuracy: 0.8076
# 67/67 [==============================] - 6s 37ms/step - loss: 0.8394 - accuracy: 0.7911 - val_loss: 0.4963 - val_accuracy: 0.8032
# 42/42 [==============================] - 1s
# 34/34 [==============================] - 8s 82ms/step - loss: 0.5327 - accuracy: 0.7851 - val_loss: 0.4984 - val_accuracy: 0.7844
# 21/21 [==============================] - 1s 21ms/step - loss: 0.4904 - accuracy: 0.7926
# 34/34 [==============================] - 7s 68ms/step - loss: 0.4892 - accuracy: 0.7991 - val_loss: 0.4632 - val_accuracy: 0.8032
# 21/21 [==============================] - 1s 32ms/step - loss: 0.4761 - accuracy: 0.7885
# 34/34 [==============================] - 8s 77ms/step - loss: 0.5052 - accuracy: 0.7707 - val_loss: 0.4871 - val_accuracy: 0.8032
# 21/21 [==============================] - 1s 26ms/step - loss: 0.4613 - accuracy: 0.8076
# 34/34 [==============================] - 9s 94ms/step - loss: 0.5057 - accuracy: 0.7968 - val_loss: 0.4712 - val_accuracy: 0.7844
# 21/21 [==============================] - 1s 25ms/step - loss: 0.4659 - accuracy: 0.7926
# 34/34 [==============================] - 9s 82ms/step - loss: 2.7450 - accuracy: 0.7888 - val_loss: 0.4977 - val_accuracy: 0.8032
# 21/21 [==============================] - 0s 6ms/step - loss: 0.5205 - accuracy: 0.7885
# 34/34 [==============================] - 8s 34ms/step - loss: 2.0616 - accuracy: 0.7768 - val_loss: 0.4960 - val_accuracy: 0.8032
# 21/21 [==============================] - 0s 15ms/step - loss: 0.4898 - accuracy: 0.8076
# 34/34 [==============================] - 8s 41ms/step - loss: 4.7341 - accuracy: 0.7982 - val_loss: 0.5313 - val_accuracy: 0.7844
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5179 - accuracy: 0.7926
# 200/200 [==============================] - 3s 6ms/step - loss: 0.4852 - accuracy: 0.7984 - val_loss: 0.4673 - val_accuracy: 0.8019
# Best: 0.796375 using {'batch_size': 32, 'lr': 0.01}
# Total runtime of the program is 72.2115867137909

# %% [markdown]
# - We can clearly see the Dask took longer than the Grid search CV.
# - Since the dataset dimensions and hyperparameter number/range were small for this example, Dask couldn't show a significant improvement.

# %% [markdown]
# ### Keras Tuner

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# #### Hyperparameters

# %% [markdown]
# - How many hidden layers should the model have?
# - How many neurons should the model have in each hidden layer?
# - Learning Rate

# %%
def build_model(h):
    model = keras.Sequential()
    for i in range(h.Int('num_layers', 2, 10)):
        model.add(layers.Dense(units=h.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=256,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            h.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %% [markdown]
# Initialize a tuner (here, RandomSearch)

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
     project_name='Job_')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
### Searching the best model on X and y train
tuner.search(X_train_normalized_df, y_train,
             epochs=5,
             validation_split = 0.2)
# Out:
# Trial 5 Complete [00h 00m 21s]
# val_accuracy: 0.8356250127156576
#
# Best val_accuracy So Far: 0.8727083206176758
# Total elapsed time: 00h 01m 35s
# INFO:tensorflow:Oracle triggered exit

# %%
## Printing the best models with their hyperparameters
tuner.results_summary()
# Out:
# Results summary
# Results in .\Job_
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000002C4A758F400>
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 160
# units_1: 160
# learning_rate: 0.001
# units_2: 224
# units_3: 128
# units_4: 224
# units_5: 64
# units_6: 160
# units_7: 64
# units_8: 32
# Score: 0.8727083206176758
# Trial summary
# Hyperparameters:
# num_layers: 8
# units_0: 160
# units_1: 64
# learning_rate: 0.001
# units_2: 160
# units_3: 64
# units_4: 192
# units_5: 32
# units_6: 224
# units_7: 96
# units_8: 192
# Score: 0.8702083428700765
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 64
# units_1: 96
# learning_rate: 0.001
# units_2: 96
# units_3: 224
# units_4: 256
# units_5: 160
# units_6: 192
# units_7: 224
# units_8: 224
# Score: 0.8687500158945719
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 128
# units_1: 32
# learning_rate: 0.0001
# units_2: 160
# units_3: 160
# units_4: 160
# units_5: 192
# units_6: 96
# units_7: 128
# units_8: 96
# Score: 0.8356250127156576
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 192
# units_1: 96
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# Score: 0.8289583325386047

# %% [markdown]
# Let's create a model with the above mentioned best configuration given by Keras Tuner.

# %% [markdown]
# ### Model 7

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model7 = Sequential()
model7.add(Dense(160,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model7.add(Dense(160,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(1, activation = 'sigmoid'))

# %%
model7.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 160)               1760
#
#  dense_1 (Dense)             (None, 160)               25760
#
#  dense_2 (Dense)             (None, 224)               36064
#
#  dense_3 (Dense)             (None, 128)               28800
#
#  dense_4 (Dense)             (None, 224)               28896
#
#  dense_5 (Dense)             (None, 1)                 225
#
# =================================================================
# Total params: 121,505
# Trainable params: 121,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model7.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_7 = model7.fit(X_train_normalized_df,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 10ms/step - loss: 0.4616 - accuracy: 0.8036 - val_loss: 0.4492 - val_accuracy: 0.8138
# Epoch 2/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4043 - accuracy: 0.8286 - val_loss: 0.3868 - val_accuracy: 0.8363
# Epoch 3/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.
50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1895 - accuracy: 0.9189 - val_loss: 0.5651 - val_accuracy: 0.8400
# Epoch 36/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1762 - accuracy: 0.9261 - val_loss: 0.5973 - val_accuracy: 0.8369
# Epoch 37/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1731 - accuracy: 0.9270 - val_loss: 0.5855 - val_accuracy: 0.8219
# Epoch 38/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1712 - accuracy: 0.9272 - val_loss: 0.6121 - val_accuracy: 0.8438
# Epoch 39/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1556 - accuracy: 0.9319 - val_loss: 0.7167 - val_accuracy: 0.8306
# Epoch 40/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1691 - accuracy: 0.9289 - val_loss: 0.6229 - val_accuracy: 0.8250
# Epoch 41/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1537 - accuracy: 0.9348 - val_loss: 0.6762 - val_accuracy: 0.8319
# Epoch 42/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1463 - accuracy: 0.9386 - val_loss: 0.7300 - val_accuracy: 0.8363
# Epoch 43/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1364 - accuracy: 0.9461 - val_loss: 0.7569 - val_accuracy: 0.8369
# Epoch 44/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1294 - accuracy: 0.9417 - val_loss: 0.7480 - val_accuracy: 0.8263
# Epoch 45/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1187 - accuracy: 0.9502 - val_loss: 0.7994 - val_accuracy: 0.8288
# Epoch 46/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1302 - accuracy: 0.9450 - val_loss: 0.7974 - val_accuracy: 0.8250
# Epoch 47/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1337 - accuracy: 0.9447 - val_loss: 0.7900 - val_accuracy: 0.8188
# Epoch 48/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1272 - accuracy: 0.9448 - val_loss: 0.8052 - val_accuracy: 0.8194
# Epoch 49/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1042 - accuracy: 0.9583 - val_loss: 0.9132 - val_accuracy: 0.8281
# Epoch 50/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1079 - accuracy: 0.9553 - val_loss: 0.8444 - val_accuracy: 0.8188

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_7.history['loss'])
plt.plot(history_7.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that the train and validation curves show overfitted model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat7 = model7.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat7 = yhat7[:, 0]
# calculate roc curves
fpr, tpr, thresholds7 = roc_curve(y_test, yhat7)
# calculate the g-mean for each threshold
gmeans7 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans7)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds7[ix], gmeans7[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 3ms/step
# Best Threshold=0.957229, G-Mean=0.655

# %%
y_pred_e7=model7.predict(X_test_normalized_df)
y_pred_e7 = (y_pred_e7 > thresholds7[ix])
y_pred_e7
# Out:
# 63/63 [==============================] - 0s 3ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm7=confusion_matrix(y_test, y_pred_e7)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm7, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr7=metrics.classification_report(y_test,y_pred_e7)
print(cr7)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82      1593
#            1       0.39      0.55      0.45       407
#
#     accuracy                           0.73      2000
#    macro avg       0.63      0.66      0.64      2000
# weighted avg       0.77      0.73      0.75      2000

# %% [markdown]
# After using the suggested hyperparameters from Keras Tuner, the recall score and the False Negative rate have improved overall but still less than our best optimized model with Grid search CV so far.

# %% [markdown]
# ### SMOTE + Keras Tuner

# %%
##Applying SMOTE on train and test
from imblearn.over_sampling import SMOTE
smote=SMOTE(sampling_strategy='not majority')
X_sm , y_sm = smote.fit_resample(X_train_normalized_df,y_train)

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def build_model_2(h):
    model = keras.Sequential()
    for i in range(h.Int('num_layers', 2, 10)):
        model.add(layers.Dense(units=h.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=256,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            h.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner_2 = RandomSearch(
    build_model_2,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    project_name='Job_Switch')

# %%
tuner_2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner_2.search(X_sm, y_sm,
             epochs=5,
             validation_split = 0.2)
# Out:
# Trial 5 Complete [00h 00m 32s]
# val_accuracy: 0.6225797931353251
#
# Best val_accuracy So Far: 0.7459445397059122
# Total elapsed time: 00h 02m 27s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner_2.results_summary()
# Out:
# Results summary
# Results in .\Job_Switch
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000002C4A628A440>
# Trial summary
# Hyperparameters:
# num_layers: 8
# units_0: 160
# units_1: 64
# learning_rate: 0.001
# units_2: 160
# units_3: 64
# units_4: 192
# units_5: 32
# units_6: 224
# units_7: 96
# units_8: 192
# Score: 0.7459445397059122
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 160
# units_1: 160
# learning_rate: 0.001
# units_2: 224
# units_3: 128
# units_4: 224
# units_5: 64
# units_6: 160
# units_7: 64
# units_8: 32
# Score: 0.7418890595436096
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 64
# units_1: 96
# learning_rate: 0.001
# units_2: 96
# units_3: 224
# units_4: 256
# units_5: 160
# units_6: 192
# units_7: 224
# units_8: 224
# Score: 0.7021193305651346
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 128
# units_1: 32
# learning_rate: 0.0001
# units_2: 160
# units_3: 160
# units_4: 160
# units_5: 192
# units_6: 96
# units_7: 128
# units_8: 96
# Score: 0.6225797931353251
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 192
# units_1: 96
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# Score: 0.6134222745895386

# %%
model9 = Sequential()
model9.add(Dense(160,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model9.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(160,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(192,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(96,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(1, activation = 'sigmoid'))
      #Compiling the ANN with Adam optimizer and binary cross entropy loss function 
optimizer = tf.keras.optimizers.Adam(0.001)
model9.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_9 = model9.fit(X_sm,y_sm,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 160/160 [==============================] - 3s 8ms/step - loss: 0.5741 - accuracy: 0.7021 - val_loss: 0.5974 - val_accuracy: 0.5797
# Epoch 2/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4972 - accuracy: 0.7540 - val_loss: 1.2029 - val_accuracy: 0.2732
# Epoch 3/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4660 - accuracy: 0.7763 - val_loss: 0.6158 - val_accuracy: 0.6672
# Epoch 4/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.4389 - accuracy: 0.7913 - val_loss: 0.5403 - val_accuracy: 0.7347
# Epoch 5/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.4209 - accuracy: 0.8027 - val_loss: 0.6042 - val_accuracy: 0.6998
# Epoch 6/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.4116 - accuracy: 0.8115 - val_loss: 0.4674 - val_accuracy: 0.7704
# Epoch 7/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.4028 - accuracy: 0.8102 - val_loss: 0.8143 - val_accuracy: 0.5930
# Epoch 8/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3958 - accuracy: 0.8163 - val_loss: 0.4898 - val_accuracy: 0.7488
# Epoch 9/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3839 - accuracy: 0.8209 - val_loss: 0.5956 - val_accuracy: 0.6962
# Epoch 10/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.3720 - accuracy: 0.8225 - val_loss: 0.5182 - val_accuracy: 0.7661
# Epoch 11/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3717 - accuracy: 0.8241 - val_loss: 0.3785 - val_accuracy: 0.8014
# Epoch 12/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3614 - accuracy: 0.8341 - val_loss: 0.8458 - val_accuracy: 0.5942
# Epoch 13/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3516 - accuracy: 0.8359 - val_loss: 0.4198 - val_accuracy: 0.8116
# Epoch 14/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3467 - accuracy: 0.8375 - val_loss: 0.5953 - val_accuracy: 0.6951
# Epoch 15/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3354 - accuracy: 0.8424 - val_loss: 0.4291 - val_accuracy: 0.8226
# Epoch 16/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3259 - accuracy: 0.8531 - val_loss: 0.4426 - val_accuracy: 0.8210
# Epoch 17/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3180 - accuracy: 0.8544 - val_loss: 0.5415 - val_accuracy: 0.7359
# Epoch 18/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3122 - accuracy: 0.8602 - val_loss: 0.4752 - val_accuracy: 0.7798
# Epoch 19/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3099 - accuracy: 0.8569 - val_loss: 0.3586 - val_accuracy: 0.8642
# Epoch 20/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2959 - accuracy: 0.8644 - val_loss: 0.4199 - val_accuracy: 0.8308
# Epoch 21/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2917 - accuracy: 0.8663 - val_loss: 0.4783 - val_accuracy: 0.7998
# Epoch 22/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2794 - accuracy: 0.8714 - val_loss: 0.4634 - val_accuracy: 0.7704
# Epoch 23/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2827 - accuracy: 0.8722 - val_loss: 0.4696 - val_accuracy: 0.8034
# Epoch 24/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2688 - accuracy: 0.8777 - val_loss: 0.3980 - val_accuracy: 0.8493
# Epoch 25/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2623 - accuracy: 0.8829 - val_loss: 0.3201 - val_accuracy: 0.8870
# Epoch 26/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2583 - accuracy: 0.8858 - val_loss: 0.3365 - val_accuracy: 0.8662
# Epoch 27/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2486 - accuracy: 0.8922 - val_loss: 0.3875 - val_accuracy: 0.8359
# Epoch 28/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2429 - accuracy: 0.8921 - val_loss: 0.3522 - val_accuracy: 0.8622
# Epoch 29/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2363 - accuracy: 0.8956 - val_loss: 0.3174 - val_accuracy: 0.8552
# Epoch 30/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2260 - accuracy: 0.9029 - val_loss: 0.2875 - val_accuracy: 0.8889
# Epoch 31/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2289 - accuracy: 0.8992 - val_loss: 0.4760 - val_accuracy: 0.7720
# Epoch 32/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2114 - accuracy: 0.9095 - val_loss: 0.2350 - val_accuracy: 0.9144
# Epoch 33/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2108 - accuracy: 0.9055 - val_loss: 0.4002 - val_accuracy: 0.8430
# Epoch 34/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1950 - accuracy: 0.9140 - val_loss: 0.4109 - val_accuracy: 0.8316
# Epoch 35/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1947 - accuracy: 0.9142 - val_loss: 0.3036 - val_accuracy: 0.8658
# Epoch 36/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.1798 - accuracy: 0.9237 - val_loss: 0.4369 - val_accuracy: 0.8359
# Epoch 37/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1935 - accuracy: 0.9161 - val_loss: 0.3864 - val_accuracy: 0.8336
# Epoch 38/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1738 - accuracy: 0.9258 - val_loss: 0.2640 - val_accuracy: 0.9109
# Epoch 39/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.1664 - accuracy: 0.9290 - val_loss: 0.2174 - val_accuracy: 0.9278
# Epoch 40/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1705 - accuracy: 0.9257 - val_loss: 0.2834 - val_accuracy: 0.9046
# Epoch 41/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1699 - accuracy: 0.9265 - val_loss: 0.2776 - val_accuracy: 0.9007
# Epoch 42/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1593 - accuracy: 0.9327 - val_loss: 0.4007 - val_accuracy: 0.8438
# Epoch 43/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.1628 - accuracy: 0.9311 - val_loss: 0.2984 - val_accuracy: 0.8925
# Epoch 44/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.1540 - accuracy: 0.9364 - val_loss: 0.3140 - val_accuracy: 0.8697
# Epoch 45/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.1472 - accuracy: 0.9390 - val_loss: 0.2590 - val_accuracy: 0.9054
# Epoch 46/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.1427 - accuracy: 0.9407 - val_loss: 0.4170 - val_accuracy: 0.8458
# Epoch 47/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.1412 - accuracy: 0.9417 - val_loss: 0.2315 - val_accuracy: 0.9097
# Epoch 48/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.1404 - accuracy: 0.9432 - val_loss: 0.3031 - val_accuracy: 0.8905
# Epoch 49/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.1257 - accuracy: 0.9452 - val_loss: 0.2661 - val_accuracy: 0.8995
# Epoch 50/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.1262 - accuracy: 0.9490 - val_loss: 0.3387 - val_accuracy: 0.8799

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_9.history['loss'])
plt.plot(history_9.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that there is a lot of noise in the model.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat9 = model9.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat9 = yhat9[:, 0]
# calculate roc curves
fpr, tpr, thresholds9 = roc_curve(y_test, yhat9)
# calculate the g-mean for each threshold
gmeans9 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans9)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds9[ix], gmeans9[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 4ms/step
# Best Threshold=0.770653, G-Mean=0.670

# %%
y_pred_e9=model9.predict(X_test_normalized_df)
y_pred_e9 = (y_pred_e9 > thresholds9[ix])
y_pred_e9
# Out:
# 63/63 [==============================] - 0s 3ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm9=confusion_matrix(y_test, y_pred_e9)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm9, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr6=metrics.classification_report(y_test,y_pred_e9)
print(cr6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.68      0.77      1593
#            1       0.35      0.65      0.45       407
#
#     accuracy                           0.68      2000
#    macro avg       0.62      0.67      0.61      2000
# weighted avg       0.78      0.68      0.71      2000

# %% [markdown]
# Overall the results are no better than the Keras Tuner alone model. From the loss curves of train and validation, the model seems to have overfit.
#
# Let's use Grid Search CV and see if we can increase the model's performance on the metrics.

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v7(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))
    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v7, verbose=1)

# %%
# define the grid search parameters
param_grid = {
    'batch_size':[32, 64, 128],
    "lr":[0.001,0.01,0.1],}

kfold_splits = 3
grid = GridSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)
grid_result = grid.fit(X_train_normalized_df, y_train,validation_split=0.2,verbose=1)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 200/200 [==============================] - 2s 6ms/step - loss: 0.4812 - accuracy: 0.7977 - val_loss: 0.4529 - val_accuracy: 0.8075

# %%
# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
# Out:
# Best: 0.802376 using {'batch_size': 32, 'lr': 0.01}

# %%
estimator_v7=create_model_v7(batch_size=grid_result.best_params_['batch_size'],lr=grid_result.best_params_['lr'])

estimator_v7.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2816
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,081
# Trainable params: 46,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(grid_result.best_params_['lr'])
estimator_v7.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_7=estimator_v7.fit(X_sm, y_sm, epochs=50, batch_size = grid_result.best_params_['batch_size'], verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 319/319 [==============================] - 3s 7ms/step - loss: 0.5842 - accuracy: 0.6924 - val_loss: 0.6440 - val_accuracy: 0.6024
# Epoch 2/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.5139 - accuracy: 0.7362 - val_loss: 0.9370 - val_accuracy: 0.3132
# Epoch 3/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.5060 - accuracy: 0.7546 - val_loss: 0.6089 - val_accuracy: 0.7182
# Epoch 4/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4916 - accuracy: 0.7593 - val_loss: 0.6967 - val_accuracy: 0.5373
# Epoch 5/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4872 - accuracy: 0.7640 - val_loss: 0.7238 - val_accuracy: 0.4992
# Epoch 6/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4867 - accuracy: 0.7646 - val_loss: 0.5594 - val_accuracy: 0.7115
# Epoch 7/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4808 - accuracy: 0.7724 - val_loss: 0.7637 - val_accuracy: 0.4941
# Epoch 8/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.4769 - accuracy: 0.7697 - val_loss: 0.5870 - val_accuracy: 0.7053
# Epoch 9/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4747 - accuracy: 0.7705 - val_loss: 0.8118 - val_accuracy: 0.5973
# Epoch 10/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4729 - accuracy: 0.7767 - val_loss: 0.6362 - val_accuracy: 0.6538
# Epoch 11/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4670 - accuracy: 0.7737 - val_loss: 0.5733 - val_accuracy: 0.6856
# Epoch 12/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.4735 - accuracy: 0.7721 - val_loss: 0.8888 - val_accuracy: 0.4898
# Epoch 13/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.4724 - accuracy: 0.7757 - val_loss: 0.7495 - val_accuracy: 0.5126
# Epoch 14/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4660 - accuracy: 0.7811 - val_loss: 0.7698 - val_accuracy: 0.5436
# Epoch 15/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4636 - accuracy: 0.7808 - val_loss: 0.7600 - val_accuracy: 0.5918
# Epoch 16/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4580 - accuracy: 0.7819 - val_loss: 0.6890 - val_accuracy: 0.7068
# Epoch 17/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4574 - accuracy: 0.7820 - val_loss: 0.6421 - val_accuracy: 0.6346
# Epoch 18/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4603 - accuracy: 0.7858 - val_loss: 0.6702 - val_accuracy: 0.5577
# Epoch 19/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4583 - accuracy: 0.7818 - val_loss: 0.5236 - val_accuracy: 0.6919
# Epoch 20/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4545 - accuracy: 0.7851 - val_loss: 0.7022 - val_accuracy: 0.6342
# Epoch 21/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4572 - accuracy: 0.7887 - val_loss: 0.7001 - val_accuracy: 0.5977
# Epoch 22/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4613 - accuracy: 0.7819 - val_loss: 0.7139 - val_accuracy: 0.6389
# Epoch 23/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4505 - accuracy: 0.7848 - val_loss: 0.6853 - val_accuracy: 0.7779
# Epoch 24/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4505 - accuracy: 0.7879 - val_loss: 0.5911 - val_accuracy: 0.6958
# Epoch 25/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.4551 - accuracy: 0.7834 - val_loss: 0.5290 - val_accuracy: 0.7618
# Epoch 26/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.4516 - accuracy: 0.7867 - val_loss: 0.5523 - val_accuracy: 0.7520
# Epoch 27/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4553 - accuracy: 0.7844 - val_loss: 0.6662 - val_accuracy: 0.5859
# Epoch 28/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4574 - accuracy: 0.7841 - val_loss: 0.6370 - val_accuracy: 0.6986
# Epoch 29/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4530 - accuracy: 0.7865 - val_loss: 0.5325 - val_accuracy: 0.6637
# Epoch 30/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4524 - accuracy: 0.7908 - val_loss: 0.5226 - val_accuracy: 0.7284
# Epoch 31/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4522 - accuracy: 0.7860 - val_loss: 0.8299 - val_accuracy: 0.5608
# Epoch 32/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4554 - accuracy: 0.7839 - val_loss: 0.4820 - val_accuracy: 0.7830
# Epoch 33/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4503 - accuracy: 0.7857 - val_loss: 0.6541 - val_accuracy: 0.6633
# Epoch 34/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4500 - accuracy: 0.7911 - val_loss: 0.6073 - val_accuracy: 0.7064
# Epoch 35/50
# 319/319 [==============================] - 1s 4ms/step - loss: 0.4478 - accuracy: 0.7939 - val_loss: 0.5749 - val_accuracy: 0.6637
# Epoch 36/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4535 - accuracy: 0.7854 - val_loss: 0.5758 - val_accuracy: 0.7578
# Epoch 37/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4482 - accuracy: 0.7937 - val_loss: 0.6938 - val_accuracy: 0.6695
# Epoch 38/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4497 - accuracy: 0.7909 - val_loss: 0.6142 - val_accuracy: 0.6609
# Epoch 39/50
# 319/319 [==============================] - 2s 7ms/step - loss: 0.4450 - accuracy: 0.7871 - val_loss: 0.5058 - val_accuracy: 0.6711
# Epoch 40/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4490 - accuracy: 0.7908 - val_loss: 0.5939 - val_accuracy: 0.6589
# Epoch 41/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4487 - accuracy: 0.7901 - val_loss: 0.5507 - val_accuracy: 0.7139
# Epoch 42/50
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4446 - accuracy: 0.7943 - val_loss: 0.6184 - val_accuracy: 0.6578
# Epoch 43/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4471 - accuracy: 0.7890 - val_loss: 0.6135 - val_accuracy: 0.6370
# Epoch 44/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4476 - accuracy: 0.7924 - val_loss: 0.5871 - val_accuracy: 0.6052
# Epoch 45/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4440 - accuracy: 0.7924 - val_loss: 0.5877 - val_accuracy: 0.6782
# Epoch 46/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4473 - accuracy: 0.7892 - val_loss: 0.6899 - val_accuracy: 0.5989
# Epoch 47/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4464 - accuracy: 0.7931 - val_loss: 0.5445 - val_accuracy: 0.7162
# Epoch 48/50
# 319/319 [==============================] - 1s 5ms/step - loss: 0.4439 - accuracy: 0.7909 - val_loss: 0.7244 - val_accuracy: 0.6456
# Epoch 49/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4475 - accuracy: 0.7898 - val_loss: 0.5827 - val_accuracy: 0.6797
# Epoch 50/50
# 319/319 [==============================] - 2s 5ms/step - loss: 0.4419 - accuracy: 0.7936 - val_loss: 0.5107 - val_accuracy: 0.7005

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_7.history['loss'])
plt.plot(history_7.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we observe that there is a lot of noise in the model.
#
# Grid Search CV also does not seem to work that well on the SMOTE data.

# %%
from sklearn.metrics import roc_curve

from matplotlib import pyplot


# predict probabilities
yhat10 = estimator_v7.predict(X_test_normalized_df)
# keep probabilities for the positive outcome only
yhat10 = yhat10[:, 0]
# calculate roc curves
fpr, tpr, thresholds10 = roc_curve(y_test, yhat10)
# calculate the g-mean for each threshold
gmeans10 = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans10)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds10[ix], gmeans10[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 63/63 [==============================] - 0s 4ms/step
# Best Threshold=0.656180, G-Mean=0.694

# %%
y_pred_e10=estimator_v7.predict(X_test_normalized_df)
y_pred_e10 = (y_pred_e10 > thresholds10[ix])
y_pred_e10
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
#Calculating the confusion matrix 
from sklearn.metrics import confusion_matrix
cm10=confusion_matrix(y_test, y_pred_e10)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Churned','Churned']
make_confusion_matrix(cm10, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 
from sklearn import metrics
cr10=metrics.classification_report(y_test,y_pred_e10)
print(cr10)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.78      1593
#            1       0.37      0.69      0.48       407
#
#     accuracy                           0.69      2000
#    macro avg       0.63      0.69      0.63      2000
# weighted avg       0.79      0.69      0.72      2000

# %% [markdown]
# Oversampling using SMOTE did not help improve the recall score.
#
# In this dataset, the SMOTE oversampling technique does not work well, as both the models we tried building have overfitted on the training dataset.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Our final model here can be Model 6, which uses the Dropout regularization technique and the Grid Search CV for the optimization of hyperparameters. As we saw, it works well on the imbalanced dataset.

# %% [markdown]
# ### Suggested Areas of Improvement

# %% [markdown]
# Build any one Machine Learning model, and use that to get the feature importance of the variables. Try to use that in the neural network model.
#
# We can also do better feature engineerning by removing the flaws of the skewed variables if required.

# %% [markdown]
# ### Business Recommendations

# %% [markdown]
# - The Bank management can deploy the final model from this exercise to identify with a reasonable degree of accuracy whether an customer is likely to churn or not, and this process seems to be easier and more time-efficient than other methods.
# - From EDA, we noticed that the customers from Germany are more likey to churn compared to France and Spain. So the Bank management can take some important measures according to the geography.
# - Similary we noticed that the customers with higher Age like 45 or above are more likely to churn so measures can be taken to incentivize such customers.
